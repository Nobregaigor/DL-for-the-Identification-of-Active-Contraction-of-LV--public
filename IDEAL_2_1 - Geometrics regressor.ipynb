# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import os
import pathlib
import matplotlib.pyplot as plt
import matplotlib
from tensorflow.keras import layers

# %% [markdown]
# ## formatting

# %%
float_formatter = "{:.5f}".format
np.set_printoptions(formatter={'float_kind':float_formatter})

plt.style.use('default')
# %matplotlib inline

matplotlib.rcParams.update({'font.size': 10})

# %% [markdown]
# ## Paths and directories

# %%
ROOT_DIR = pathlib.Path("./")
DATA_DIR = ROOT_DIR/"geometrics_ideal_clean"

csv_header_filepath = DATA_DIR/"header.json"

train_dir = DATA_DIR/"train"
valid_dir = DATA_DIR/"valid"
test_dir = DATA_DIR/"test"

model_save_root = ROOT_DIR/"models"

# %%
csv_header_filepath
# Out:
# PosixPath('/content/drive/MyDrive/Research/PAPER_1_CODE/geometrics_ideal_clean/header.json')

# %%
import json
with open(csv_header_filepath, "r") as jsonfile:
  jsondata = json.load(jsonfile)
header = jsondata["headers"]

# %% [markdown]
# # Utils

# %% [markdown]
# ## Modules

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense

class ResnetBlock(tf.keras.Model):
  def __init__(self, units, dropout_rate=0.001, **kwargs):
    super(ResnetBlock, self).__init__(**kwargs)

    self.units=units
    self.dropout_rate=dropout_rate
    self.dense1 = Dense(units)
    self.dense2 = Dense(units)
    self.dense3 = Dense(units)

    self.dropout = Dropout(dropout_rate)
  
  @tf.function()
  def call(self, input_tensor, training=False):
    x = self.dense1(input_tensor, training=training)
    x = self.dropout(x)
    x = self.dense2(x, training=training)
    x = self.dropout(x)
    x = self.dense3(x, training=training)
    x = self.dropout(x)

    x += input_tensor
    return tf.nn.relu(x)
  
  def get_config(self):
      config = super(ResnetBlock, self).get_config()
      config.update({"units": self.units, "dropout_rate": self.dropout_rate})
      return config

# %%
import tensorflow as tf

class NormalizedBaseClass(tf.keras.losses.Loss):
  def __init__(self, lb=[], up=[], indices=[], epsilon=1e-12, dtype=tf.float32, **kwargs):
    super().__init__(**kwargs)

    self.indices = indices
    self.use_indices = True if len(indices) > 0 else False

    self.epsilon = epsilon
    self.dtype = dtype

    self.lowBound = self.setBounds(lb)
    self.uppBound = self.setBounds(up)
    self.epsilon_tensor = self.setEpsilonTensor(epsilon)
    
    self._dividion_denomiator = tf.maximum(tf.subtract(self.uppBound, self.lowBound, name="denom_sub"), self.epsilon_tensor)    
  
  def setBounds(self, bd):
    return tf.constant(self.gather(bd), dtype=self.dtype)
  
  def setEpsilonTensor(self,epsilon):
    return tf.constant(self.epsilon, dtype=self.dtype, shape=self.lowBound.shape)

  def gather(self, tensor, axis=-1):
    if not self.use_indices:
      return tensor
    gathered = tf.gather(tensor, self.indices, axis=axis)
    if gathered.dtype != self.dtype:
      gathered = tf.cast(gathered, self.dtype)
    return gathered

  def normalize(self, X, gather_x=True):
    if gather_x:
      X = self.gather(X)
    S = tf.subtract(X, self.lowBound, name="norm_sub")
    return tf.divide(S, self._dividion_denomiator, name="norm_div")
  
  def convert_inputs(self, y_true, y_pred, set_dtype=True):
    y_pred = tf.convert_to_tensor(y_pred)    
    y_true = tf.cast(y_true, y_pred.dtype)
    if set_dtype:
      self.setDtype(y_pred.dtype)
    return y_true, y_pred

  def setDtype(self, dtype):
    self.dtype = dtype

  def get_config(self):
    base_config = super().get_config()
    return {**base_config, "lb":self.lb, "up": self.up, "epsilon": self.epsilon}
  
class NormalizedMeanAbsoluteError(NormalizedBaseClass):
  def __init__(self, lb=[], up=[], indices=[], **kwargs):
    super().__init__(**kwargs)
  
  def call(self, y_true, y_pred):
    y_true, y_pred = self.convert_inputs(y_true, y_pred)
    y_true_norm, y_pred_norm = self.normalize(y_true), self.normalize(y_pred, False)
    return tf.math.reduce_mean(tf.abs(y_pred_norm - y_true_norm), axis=-1)
  def get_config(self):
    base_config = super().get_config()
    return {**base_config, "lb":self.lb, "up": self.up, "epsilon": self.epsilon}

class NormalizedMeanSquaredError(NormalizedBaseClass):
  def __init__(self, **kwargs):
    super().__init__(**kwargs)
  
  def call(self, y_true, y_pred):
    y_true, y_pred = self.convert_inputs(y_true, y_pred)
    y_true_norm, y_pred_norm = self.normalize(y_true), self.normalize(y_pred, False)
    return tf.math.reduce_mean(tf.math.square(y_pred_norm - y_true_norm), axis=-1)
  def get_config(self):
    base_config = super().get_config()
    return {**base_config, "lb":self.lb, "up": self.up, "epsilon": self.epsilon}

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense

def build_norm_layer(batch_size, header, labels, feats, name="norm",int_labels=False):
  from tensorflow.keras.layers.experimental import preprocessing
  ds_norm  = csv_ds_reader(train_dir, header, labels, feats, int_labels=int_labels, batch_size=batch_size)
  norm_layer = preprocessing.Normalization(name=name)
  for (xs, _) in ds_norm.take(1):
    norm_layer.adapt(xs)
  return norm_layer

class GM4_Regressor_Model(tf.keras.Model):
  def __init__(self, n_units, n_blocks, norm_layer, n_output_labels, **kwargs):
    super(GM4_Regressor_Model, self).__init__(**kwargs)

    self.n_units = n_units
    self.n_blocks = n_blocks
    self.norm = norm_layer

    self.d1 = Dense(self.n_units, activation="relu")
    self.l1 = [ResnetBlock(self.n_units, dropout_rate=0.001) for _ in range(n_blocks)]
    self.l2 = [ResnetBlock(self.n_units*2, dropout_rate=0.001) for _ in range(n_blocks)]
    self.l3 = [ResnetBlock(self.n_units*4, dropout_rate=0.001) for _ in range(n_blocks)]

    self.d2 = Dense(self.n_units*2, activation="relu")
    self.d3 = Dense(self.n_units*4, activation="relu")

    self.tail = [
      layers.ActivityRegularization(0.0001, 0.0001),
      Dense(n_output_labels, name="gr_body_out"),
    ]

  def call(self, input_tensor, training=False):
    x_norm = self.norm(input_tensor)
    # x = tf.concat([x_norm, x_bins], axis=1)
    x = self.d1(x_norm)
    for layer in self.l1:
      x = layer(x)
    x = self.d2(x)
    x = self.d3(x)
    for layer in self.tail:
      x = layer(x)
    return x

  def get_config(self):
      # config = super(CM4_Model, self).get_config()
      return {"n_units": self.n_units, "n_blocks": self.n_blocks}

# %% [markdown]
# ## utils

# %%
import json
import pandas as pd
import numpy as np
import tensorflow as tf

def get_indexes(header, of_keys):
  return [header[key]+1 for key in of_keys]

def csv_ds_reader(filepaths, 
                  header,
                  label_keys,
                  feature_keys,
                  int_labels=False,
                  reshape_to=None,
                  batch_size=32,
    repeat=1, n_readers=5, 
    shuffle_buffer_size=10000, 
    cache=True, 
    n_read_threads=None, 
    n_parse_threads=5):
  
  label_indexes = get_indexes(header, label_keys)
  feature_indexes = get_indexes(header, feature_keys)
  
  def get_features_labels(line):
    """
      Re-structures DS to read csv field and return 'features, labels'
    """
    defs = [0.] * (len(header) + 1) #n_labels
    fields = tf.io.decode_csv(line, record_defaults=defs)
 
    # cm-lookup -> CM1 -> (CMs), (FB, PV)
    _labels  = tf.stack([fields[i] for i in label_indexes])
    features = tf.stack([fields[i] for i in feature_indexes])
   
    try:
      tf.debugging.check_numerics(_labels, message='Checking _labels')
    except Exception as e:
      assert "Checking labels: Tensor had NaN values" in e.message
    
    try:
      tf.debugging.check_numerics(features, message='Checking features')
    except Exception as e:
      assert "Checking features: Tensor had NaN values" in e.message

    if int_labels is True:
      _labels = tf.cast(_labels, tf.int32, "label_int")

    if reshape_to is not None:
      _labels = tf.reshape(_labels, reshape_to)
  
    return features, _labels
  
  # get files
  ds = tf.data.Dataset.list_files(str(pathlib.Path(filepaths)/'*.csv'))
  # read in random order cycling through files
  ds = ds.interleave(
      lambda filepath: tf.data.TextLineDataset(filepath).skip(1),
      cycle_length=n_readers, num_parallel_calls=n_read_threads
  )
  # shuffle and repeat
  ds = ds.shuffle(shuffle_buffer_size).repeat(repeat)
  # preprocess dataset (must provide a function)
  ds = ds.map(get_features_labels, num_parallel_calls=n_parse_threads)
  # cache dataset
  ds = ds.cache()
  ds = ds.batch(batch_size)
  ds = ds.prefetch(1)
  return ds

# %%
import json
def save_model_info(dir, features, labels, scales=[]):
  model_info = {"features": features, "labels": labels, "scales": scales}
  model_info = json.dumps(model_info)
  if not os.path.exists(dir):
    os.makedirs(dir)
  with open(dir/"info.json", "w") as jsonfile:
    jsonfile.write(model_info)

# %%
import tensorflow as tf
import matplotlib 
import matplotlib.pyplot as plt

def scatter_accuracy(ys, preds):
  try:
    if ys.shape != preds.shape:
      ys = tf.reshape(ys, preds.shape)
    e = abs(ys - preds)
    fig, ax = plt.subplots(figsize=(10,10))
    cb = ax.scatter(ys, preds, c=e, cmap="jet")
    ax.grid()
    ax.set_ylabel("Predicted")
    ax.set_xlabel("True")
    ax.set_title("Accuracy scatter plot")
    fig.colorbar(cb, ax=ax)
  except:
    print("Failed generating scatter plot.")

# %% [markdown]
# # Model features and labels

# %%
MODEL_PREFIX = "IDEAL_GM_REGRESSOR"

# %%
FEATS = ["endo", "epi", "pressure", "volume"]
LABELS = [
          "longitudinal_distance_endo", 
          "radial_distance_endo", 
          "wall_thickness", 
          "global_longitudinal_length_endo", 
          "global_circumferential_length_endo", 
          ]
BIN_LABELS = [k + "-b" for k in FEATS if k+"-b" in header.keys()]
FEATS, BIN_LABELS, LABELS
# Out:
# (['endo', 'epi', 'pressure', 'volume'],
#  ['endo-b', 'epi-b', 'pressure-b', 'volume-b'],
#  ['longitudinal_distance_endo',
#   'radial_distance_endo',
#   'wall_thickness',
#   'global_longitudinal_length_endo',
#   'global_circumferential_length_endo'])

# %% [markdown]
# # CM4: Clinical metrics Model with 4 Inputs

# %%
gm4_save_root = model_save_root/MODEL_PREFIX.upper()
gm4_best_save = gm4_save_root/"best"
gm4_best_save_weights = gm4_best_save/"weights"

# %% [markdown]
# ## Load Gamma Dataset
#
# Labels: ['gamma']
#
# Features: ['epi', 'endo', 'pressure', 'volume']

# %%
BATCH_SIZE = 500
gm4_ds_train = csv_ds_reader(train_dir, header, LABELS, FEATS, batch_size=BATCH_SIZE)
gm4_ds_valid = csv_ds_reader(valid_dir, header, LABELS, FEATS, batch_size=BATCH_SIZE)
gm4_ds_test  = csv_ds_reader(test_dir,  header, LABELS, FEATS, batch_size=BATCH_SIZE)

# %%
LABELS
# Out:
# ['longitudinal_distance_endo',
#  'radial_distance_endo',
#  'wall_thickness',
#  'global_longitudinal_length_endo',
#  'global_circumferential_length_endo']

# %%
print("CM4 train set:")
for (features, labels) in gm4_ds_train.take(1):
  print("Features: {} \nLabels: {}".format(features[0], labels[0]))
  print("Shapes -> Features: {}, Labels: {}".format(features.shape, labels.shape))
# Out:
# CM4 train set:
# Features: [48.00000 -52.00000 0.70000 0.99487]
# Labels: [94.54834 20.42753 9.80008 200.57909 128.11415]
# Shapes -> Features: (500, 4), Labels: (500, 5)

# %% [markdown]
# ### Normalization Layer

# %%
GM4_NormLayer = build_norm_layer(1000, header, LABELS, FEATS, MODEL_PREFIX+"_norm")

# %% [markdown]
# ### Arquitecture

# %%
GM4 = GM4_Regressor_Model(100, 1, GM4_NormLayer, len(LABELS))
GM4.build([None, len(FEATS)])
GM4.summary()
# Out:
# Model: "gm4__regressor__model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  IDEAL_GM_REGRESSOR_norm (No  multiple                 9
#  rmalization)
#
#  dense_100 (Dense)           multiple                  500
#
#  resnet_block_25 (ResnetBloc  multiple                 30300
#  k)
#
#  resnet_block_26 (ResnetBloc  multiple                 0 (unused)
#  k)
#
#  resnet_block_27 (ResnetBloc  multiple                 0 (unused)
#  k)
#
#  dense_110 (Dense)           multiple                  20200
#
#  dense_111 (Dense)           multiple                  80400
#
#  activity_regularization_7 (  multiple                 0
#  ActivityRegularization)
#
#  gr_body_out (Dense)         multiple                  2005
#
# =================================================================
# Total params: 133,414
# Trainable params: 133,405
# Non-trainable params: 9
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
initial_learning_rate = 1e-4
GM4Optimizer = tf.keras.optimizers.Adam(learning_rate=initial_learning_rate)
GM4Loss = tf.keras.losses.MeanSquaredError()
GM4.compile(
    loss = [GM4Loss],# tf.keras.losses.MeanSquaredLogarithmicError()],
    optimizer=GM4Optimizer,
    metrics=["mse", "mae", tf.keras.metrics.RootMeanSquaredError()]
)

# %%
GM4Callbacks = [
  tf.keras.callbacks.ReduceLROnPlateau(factor=0.7, patience=3, verbose=1),
  tf.keras.callbacks.EarlyStopping(patience=6, verbose=1, restore_best_weights=True),
]

# %%
with tf.device('/device:GPU:0'):
  gm4_TrainHistory = GM4.fit(
    gm4_ds_train,
    epochs=300, verbose=1, 
    validation_data=gm4_ds_valid,
    callbacks=GM4Callbacks
  )
# Out:
# Epoch 1/300
# 814/814 [==============================] - 37s 42ms/step - loss: 1430.6703 - mse: 1427.7838 - mae: 19.7299 - root_mean_squared_error: 37.7861 - val_loss: 213.5176 - val_mse: 210.2642 - val_mae: 9.2447 - val_root_mean_squared_error: 14.5005 - lr: 1.0000e-04
# Epoch 2/300
# 814/814 [==============================] - 6s 7ms/step - loss: 68.2399 - mse: 65.1806 - mae: 4.4832 - root_mean_squared_error: 8.0734 - val_loss: 6.8775 - val_mse: 3.9526 - val_mae: 1.3756 - val_root_mean_squared_error: 1.9881 - lr: 1.0000e-04
# Epoch 3/300
# 814/814 [==============================] - 6s 8ms/step - loss: 6.2258 - mse: 3.3548 - mae: 1.1638 - root_mean_squared_error: 1.8316 - val_loss: 4.2734 - val_mse: 1.4662 - val_mae: 0.8030 - val_root_mean_squared_error: 1.2109 - lr: 1.0000e-04
# Epoch 4/300
# 814/814 [==============================] - 5s 6ms/step - loss: 4.6848 - mse: 1.9650 - mae: 0.8317 - root_mean_squared_error: 1.4018 - val_loss: 3.4624 - val_mse: 0.8356 - val_mae: 0.5940 - val_root_mean_squared_error: 0.9141 - lr: 1.0000e-04
# Epoch 5/300
# 814/814 [==============================] - 5s 7ms/step - loss: 3.9876 - mse: 1.4531 - mae: 0.6850 - root_mean_squared_error: 1.2054 - val_loss: 3.0228 - val_mse: 0.5965 - val_mae: 0.4881 - val_root_mean_squared_error: 0.7724 - lr: 1.0000e-04
# Epoch 6/300
# 814/814 [==============================] - 6s 7ms/step - loss: 3.5070 - mse: 1.1816 - mae: 0.6031 - root_mean_squared_error: 1.0870 - val_loss: 2.6788 - val_mse: 0.4670 - val_mae: 0.4198 - val_root_mean_squared_error: 0.6834 - lr: 1.0000e-04
# Epoch 7/300
# 814/814 [==============================] - 7s 9ms/step - loss: 3.1167 - mse: 1.0115 - mae: 0.5491 - root_mean_squared_error: 1.0057 - val_loss: 2.3700 - val_mse: 0.3796 - val_mae: 0.3708 - val_root_mean_squared_error: 0.6161 - lr: 1.0000e-04
# Epoch 8/300
# 814/814 [==============================] - 6s 7ms/step - loss: 2.7631 - mse: 0.8761 - mae: 0.5072 - root_mean_squared_error: 0.9360 - val_loss: 2.0971 - val_mse: 0.3179 - val_mae: 0.3318 - val_root_mean_squared_error: 0.5638 - lr: 1.0000e-04
# Epoch 9/300
# 814/814 [==============================] - 5s 6ms/step - loss: 2.4657 - mse: 0.7800 - mae: 0.4799 - root_mean_squared_error: 0.8832 - val_loss: 1.8980 - val_mse: 0.2993 - val_mae: 0.3211 - val_root_mean_squared_error: 0.5471 - lr: 1.0000e-04
# Epoch 10/300
# 814/814 [==============================] - 6s 7ms/step - loss: 2.1988 - mse: 0.6876 - mae: 0.4480 - root_mean_squared_error: 0.8292 - val_loss: 1.6686 - val_mse: 0.2387 - val_mae: 0.2784 - val_root_mean_squared_error: 0.4885 - lr: 1.0000e-04
# Epoch 11/300
# 814/814 [==============================] - 7s 9ms/step - loss: 1.9732 - mse: 0.6137 - mae: 0.4238 - root_mean_squared_error: 0.7834 - val_loss: 1.5319 - val_mse: 0.2383 - val_mae: 0.2817 - val_root_mean_squared_error: 0.4881 - lr: 1.0000e-04
# Epoch 12/300
# 814/814 [==============================] - 6s 7ms/step - loss: 1.7747 - mse: 0.5478 - mae: 0.4019 - root_mean_squared_error: 0.7401 - val_loss: 1.3654 - val_mse: 0.1943 - val_mae: 0.2561 - val_root_mean_squared_error: 0.4408 - lr: 1.0000e-04
# Epoch 13/300
# 814/814 [==============================] - 7s 9ms/step - loss: 1.5948 - mse: 0.4792 - mae: 0.3782 - root_mean_squared_error: 0.6922 - val_loss: 1.2107 - val_mse: 0.1460 - val_mae: 0.2183 - val_root_mean_squared_error: 0.3821 - lr: 1.0000e-04
# Epoch 14/300
# 814/814 [==============================] - 6s 8ms/step - loss: 1.4444 - mse: 0.4221 - mae: 0.3573 - root_mean_squared_error: 0.6497 - val_loss: 1.1024 - val_mse: 0.1234 - val_mae: 0.2037 - val_root_mean_squared_error: 0.3513 - lr: 1.0000e-04
# Epoch 15/300
# 814/814 [==============================] - 6s 7ms/step - loss: 1.3108 - mse: 0.3692 - mae: 0.3350 - root_mean_squared_error: 0.6076 - val_loss: 1.0035 - val_mse: 0.1005 - val_mae: 0.1878 - val_root_mean_squared_error: 0.3171 - lr: 1.0000e-04
# Epoch 16/300
# 814/814 [==============================] - 6s 7ms/step - loss: 1.2020 - mse: 0.3305 - mae: 0.3181 - root_mean_squared_error: 0.5749 - val_loss: 0.9275 - val_mse: 0.0873 - val_mae: 0.1790 - val_root_mean_squared_error: 0.2955 - lr: 1.0000e-04
# Epoch 17/300
# 814/814 [==============================] - 5s 6ms/step - loss: 1.1023 - mse: 0.2900 - mae: 0.2979 - root_mean_squared_error: 0.5385 - val_loss: 0.8800 - val_mse: 0.0934 - val_mae: 0.1908 - val_root_mean_squared_error: 0.3056 - lr: 1.0000e-04
# Epoch 18/300
# 814/814 [==============================] - 6s 8ms/step - loss: 1.0158 - mse: 0.2562 - mae: 0.2814 - root_mean_squared_error: 0.5061 - val_loss: 0.7980 - val_mse: 0.0632 - val_mae: 0.1525 - val_root_mean_squared_error: 0.2514 - lr: 1.0000e-04
# Epoch 19/300
# 814/814 [==============================] - 6s 7ms/step - loss: 0.9443 - mse: 0.2318 - mae: 0.2678 - root_mean_squared_error: 0.4814 - val_loss: 0.7518 - val_mse: 0.0619 - val_mae: 0.1567 - val_root_mean_squared_error: 0.2488 - lr: 1.0000e-04
# Epoch 20/300
# 814/814 [==============================] - 7s 9ms/step - loss: 0.8791 - mse: 0.2079 - mae: 0.2542 - root_mean_squared_error: 0.4559 - val_loss: 0.7094 - val_mse: 0.0580 - val_mae: 0.1517 - val_root_mean_squared_error: 0.2408 - lr: 1.0000e-04
# Epoch 21/300
# 814/814 [==============================] - 6s 8ms/step - loss: 0.8239 - mse: 0.1887 - mae: 0.2416 - root_mean_squared_error: 0.4344 - val_loss: 0.6947 - val_mse: 0.0783 - val_mae: 0.1882 - val_root_mean_squared_error: 0.2798 - lr: 1.0000e-04
# Epoch 22/300
# 814/814 [==============================] - 6s 8ms/step - loss: 0.7746 - mse: 0.1719 - mae: 0.2311 - root_mean_squared_error: 0.4147 - val_loss: 0.6695 - val_mse: 0.0845 - val_mae: 0.1985 - val_root_mean_squared_error: 0.2907 - lr: 1.0000e-04
# Epoch 23/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.7312 - mse: 0.1579 - mae: 0.2222 - root_mean_squared_error: 0.3974 - val_loss: 0.6346 - val_mse: 0.0770 - val_mae: 0.1897 - val_root_mean_squared_error: 0.2775 - lr: 1.0000e-04
# Epoch 24/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.6947 - mse: 0.1476 - mae: 0.2155 - root_mean_squared_error: 0.3842 - val_loss: 0.6369 - val_mse: 0.1043 - val_mae: 0.2267 - val_root_mean_squared_error: 0.3229 - lr: 1.0000e-04
# Epoch 25/300
# 814/814 [==============================] - 6s 8ms/step - loss: 0.6590 - mse: 0.1351 - mae: 0.2068 - root_mean_squared_error: 0.3675 - val_loss: 0.6120 - val_mse: 0.1014 - val_mae: 0.2249 - val_root_mean_squared_error: 0.3184 - lr: 1.0000e-04
# Epoch 26/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.6257 - mse: 0.1232 - mae: 0.1968 - root_mean_squared_error: 0.3509 - val_loss: 0.5746 - val_mse: 0.0846 - val_mae: 0.2045 - val_root_mean_squared_error: 0.2909 - lr: 1.0000e-04
# Epoch 27/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.5991 - mse: 0.1170 - mae: 0.1935 - root_mean_squared_error: 0.3421 - val_loss: 0.5409 - val_mse: 0.0701 - val_mae: 0.1842 - val_root_mean_squared_error: 0.2648 - lr: 1.0000e-04
# Epoch 28/300
# 814/814 [==============================] - 6s 8ms/step - loss: 0.5741 - mse: 0.1101 - mae: 0.1877 - root_mean_squared_error: 0.3318 - val_loss: 0.4986 - val_mse: 0.0441 - val_mae: 0.1390 - val_root_mean_squared_error: 0.2100 - lr: 1.0000e-04
# Epoch 29/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.5483 - mse: 0.1011 - mae: 0.1785 - root_mean_squared_error: 0.3180 - val_loss: 0.5174 - val_mse: 0.0803 - val_mae: 0.2031 - val_root_mean_squared_error: 0.2834 - lr: 1.0000e-04
# Epoch 30/300
# 814/814 [==============================] - 6s 7ms/step - loss: 0.5282 - mse: 0.0969 - mae: 0.1770 - root_mean_squared_error: 0.3114 - val_loss: 0.4627 - val_mse: 0.0397 - val_mae: 0.1336 - val_root_mean_squared_error: 0.1993 - lr: 1.0000e-04
# Epoch 31/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.5071 - mse: 0.0901 - mae: 0.1703 - root_mean_squared_error: 0.3001 - val_loss: 0.4422 - val_mse: 0.0327 - val_mae: 0.1200 - val_root_mean_squared_error: 0.1809 - lr: 1.0000e-04
# Epoch 32/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.4914 - mse: 0.0877 - mae: 0.1693 - root_mean_squared_error: 0.2961 - val_loss: 0.4362 - val_mse: 0.0394 - val_mae: 0.1346 - val_root_mean_squared_error: 0.1985 - lr: 1.0000e-04
# Epoch 33/300
# 814/814 [==============================] - 5s 7ms/step - loss: 0.4727 - mse: 0.0812 - mae: 0.1627 - root_mean_squared_error: 0.2850 - val_loss: 0.5093 - val_mse: 0.1259 - val_mae: 0.2615 - val_root_mean_squared_error: 0.3549 - lr: 1.0000e-04
# Epoch 34/300
# 814/814 [==============================] - 5s 7ms/step - loss: 0.4555 - mse: 0.0755 - mae: 0.1560 - root_mean_squared_error: 0.2748 - val_loss: 0.4842 - val_mse: 0.1119 - val_mae: 0.2513 - val_root_mean_squared_error: 0.3345 - lr: 1.0000e-04
# Epoch 35/300
# 814/814 [==============================] - 6s 7ms/step - loss: 0.4448 - mse: 0.0758 - mae: 0.1578 - root_mean_squared_error: 0.2753 - val_loss: 0.3872 - val_mse: 0.0236 - val_mae: 0.0996 - val_root_mean_squared_error: 0.1537 - lr: 1.0000e-04
# Epoch 36/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.4281 - mse: 0.0693 - mae: 0.1499 - root_mean_squared_error: 0.2632 - val_loss: 0.4277 - val_mse: 0.0755 - val_mae: 0.1991 - val_root_mean_squared_error: 0.2747 - lr: 1.0000e-04
# Epoch 37/300
# 814/814 [==============================] - 6s 8ms/step - loss: 0.4172 - mse: 0.0683 - mae: 0.1510 - root_mean_squared_error: 0.2614 - val_loss: 0.3796 - val_mse: 0.0362 - val_mae: 0.1292 - val_root_mean_squared_error: 0.1902 - lr: 1.0000e-04
# Epoch 38/300
# 814/814 [==============================] - 6s 7ms/step - loss: 0.4050 - mse: 0.0650 - mae: 0.1468 - root_mean_squared_error: 0.2550 - val_loss: 0.3688 - val_mse: 0.0340 - val_mae: 0.1254 - val_root_mean_squared_error: 0.1843 - lr: 1.0000e-04
# Epoch 39/300
# 814/814 [==============================] - 6s 7ms/step - loss: 0.3917 - mse: 0.0603 - mae: 0.1409 - root_mean_squared_error: 0.2455 - val_loss: 0.3483 - val_mse: 0.0214 - val_mae: 0.0959 - val_root_mean_squared_error: 0.1464 - lr: 1.0000e-04
# Epoch 40/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.3834 - mse: 0.0603 - mae: 0.1419 - root_mean_squared_error: 0.2456 - val_loss: 0.3489 - val_mse: 0.0305 - val_mae: 0.1186 - val_root_mean_squared_error: 0.1746 - lr: 1.0000e-04
# Epoch 41/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.3715 - mse: 0.0562 - mae: 0.1364 - root_mean_squared_error: 0.2371 - val_loss: 0.3319 - val_mse: 0.0204 - val_mae: 0.0919 - val_root_mean_squared_error: 0.1430 - lr: 1.0000e-04
# Epoch 42/300
# 814/814 [==============================] - 6s 7ms/step - loss: 0.3630 - mse: 0.0552 - mae: 0.1360 - root_mean_squared_error: 0.2350 - val_loss: 0.3378 - val_mse: 0.0344 - val_mae: 0.1276 - val_root_mean_squared_error: 0.1856 - lr: 1.0000e-04
# Epoch 43/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.3541 - mse: 0.0534 - mae: 0.1347 - root_mean_squared_error: 0.2312 - val_loss: 0.3261 - val_mse: 0.0295 - val_mae: 0.1171 - val_root_mean_squared_error: 0.1718 - lr: 1.0000e-04
# Epoch 44/300
# 814/814 [==============================] - 5s 7ms/step - loss: 0.3453 - mse: 0.0512 - mae: 0.1315 - root_mean_squared_error: 0.2263 - val_loss: 0.3220 - val_mse: 0.0319 - val_mae: 0.1234 - val_root_mean_squared_error: 0.1786 - lr: 1.0000e-04
# Epoch 45/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.3377 - mse: 0.0500 - mae: 0.1301 - root_mean_squared_error: 0.2236 - val_loss: 0.3177 - val_mse: 0.0338 - val_mae: 0.1269 - val_root_mean_squared_error: 0.1838 - lr: 1.0000e-04
# Epoch 46/300
# 814/814 [==============================] - 6s 7ms/step - loss: 0.3306 - mse: 0.0489 - mae: 0.1286 - root_mean_squared_error: 0.2210 - val_loss: 0.3091 - val_mse: 0.0309 - val_mae: 0.1216 - val_root_mean_squared_error: 0.1757 - lr: 1.0000e-04
# Epoch 47/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.3237 - mse: 0.0476 - mae: 0.1263 - root_mean_squared_error: 0.2181 - val_loss: 0.3072 - val_mse: 0.0346 - val_mae: 0.1295 - val_root_mean_squared_error: 0.1860 - lr: 1.0000e-04
# Epoch 48/300
# 814/814 [==============================] - 6s 7ms/step - loss: 0.3168 - mse: 0.0461 - mae: 0.1249 - root_mean_squared_error: 0.2148 - val_loss: 0.3106 - val_mse: 0.0434 - val_mae: 0.1505 - val_root_mean_squared_error: 0.2082 - lr: 1.0000e-04
# Epoch 49/300
# 814/814 [==============================] - 6s 7ms/step - loss: 0.3106 - mse: 0.0451 - mae: 0.1241 - root_mean_squared_error: 0.2123 - val_loss: 0.3219 - val_mse: 0.0599 - val_mae: 0.1798 - val_root_mean_squared_error: 0.2448 - lr: 1.0000e-04
# Epoch 50/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.3035 - mse: 0.0429 - mae: 0.1211 - root_mean_squared_error: 0.2072 - val_loss: 0.3068 - val_mse: 0.0495 - val_mae: 0.1625 - val_root_mean_squared_error: 0.2226 - lr: 1.0000e-04
# Epoch 51/300
# 814/814 [==============================] - 6s 8ms/step - loss: 0.2983 - mse: 0.0425 - mae: 0.1209 - root_mean_squared_error: 0.2061 - val_loss: 0.2748 - val_mse: 0.0217 - val_mae: 0.1000 - val_root_mean_squared_error: 0.1472 - lr: 1.0000e-04
# Epoch 52/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.2939 - mse: 0.0425 - mae: 0.1206 - root_mean_squared_error: 0.2061 - val_loss: 0.3140 - val_mse: 0.0658 - val_mae: 0.1893 - val_root_mean_squared_error: 0.2566 - lr: 1.0000e-04
# Epoch 53/300
# 814/814 [==============================] - 6s 8ms/step - loss: 0.2868 - mse: 0.0397 - mae: 0.1153 - root_mean_squared_error: 0.1992 - val_loss: 0.2855 - val_mse: 0.0413 - val_mae: 0.1451 - val_root_mean_squared_error: 0.2031 - lr: 1.0000e-04
# Epoch 54/300
# 805/814 [============================>.] - ETA: 0s - loss: 0.2829 - mse: 0.0399 - mae: 0.1170 - root_mean_squared_error: 0.1998
# Epoch 54: ReduceLROnPlateau reducing learning rate to 6.999999823165126e-05.
# 814/814 [==============================] - 5s 6ms/step - loss: 0.2829 - mse: 0.0399 - mae: 0.1170 - root_mean_squared_error: 0.1997 - val_loss: 0.2791 - val_mse: 0.0389 - val_mae: 0.1409 - val_root_mean_squared_error: 0.1972 - lr: 1.0000e-04
# Epoch 55/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.2747 - mse: 0.0353 - mae: 0.1067 - root_mean_squared_error: 0.1878 - val_loss: 0.2650 - val_mse: 0.0278 - val_mae: 0.1169 - val_root_mean_squared_error: 0.1668 - lr: 7.0000e-05
# Epoch 56/300
# 814/814 [==============================] - 6s 8ms/step - loss: 0.2723 - mse: 0.0362 - mae: 0.1100 - root_mean_squared_error: 0.1903 - val_loss: 0.2485 - val_mse: 0.0144 - val_mae: 0.0786 - val_root_mean_squared_error: 0.1199 - lr: 7.0000e-05
# Epoch 57/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.2674 - mse: 0.0346 - mae: 0.1070 - root_mean_squared_error: 0.1859 - val_loss: 0.2464 - val_mse: 0.0154 - val_mae: 0.0812 - val_root_mean_squared_error: 0.1241 - lr: 7.0000e-05
# Epoch 58/300
# 814/814 [==============================] - 6s 7ms/step - loss: 0.2642 - mse: 0.0346 - mae: 0.1070 - root_mean_squared_error: 0.1861 - val_loss: 0.2419 - val_mse: 0.0141 - val_mae: 0.0784 - val_root_mean_squared_error: 0.1187 - lr: 7.0000e-05
# Epoch 59/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.2601 - mse: 0.0336 - mae: 0.1050 - root_mean_squared_error: 0.1834 - val_loss: 0.2448 - val_mse: 0.0204 - val_mae: 0.0963 - val_root_mean_squared_error: 0.1429 - lr: 7.0000e-05
# Epoch 60/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.2565 - mse: 0.0332 - mae: 0.1049 - root_mean_squared_error: 0.1823 - val_loss: 0.2487 - val_mse: 0.0276 - val_mae: 0.1156 - val_root_mean_squared_error: 0.1661 - lr: 7.0000e-05
# Epoch 61/300
# 814/814 [==============================] - 5s 7ms/step - loss: 0.2529 - mse: 0.0327 - mae: 0.1044 - root_mean_squared_error: 0.1809 - val_loss: 0.2323 - val_mse: 0.0138 - val_mae: 0.0766 - val_root_mean_squared_error: 0.1175 - lr: 7.0000e-05
# Epoch 62/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.2496 - mse: 0.0323 - mae: 0.1030 - root_mean_squared_error: 0.1797 - val_loss: 0.2491 - val_mse: 0.0338 - val_mae: 0.1302 - val_root_mean_squared_error: 0.1840 - lr: 7.0000e-05
# Epoch 63/300
# 814/814 [==============================] - 6s 7ms/step - loss: 0.2458 - mse: 0.0313 - mae: 0.1017 - root_mean_squared_error: 0.1769 - val_loss: 0.2297 - val_mse: 0.0170 - val_mae: 0.0872 - val_root_mean_squared_error: 0.1303 - lr: 7.0000e-05
# Epoch 64/300
# 814/814 [==============================] - 6s 8ms/step - loss: 0.2436 - mse: 0.0319 - mae: 0.1030 - root_mean_squared_error: 0.1785 - val_loss: 0.2332 - val_mse: 0.0232 - val_mae: 0.1041 - val_root_mean_squared_error: 0.1524 - lr: 7.0000e-05
# Epoch 65/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.2394 - mse: 0.0303 - mae: 0.0999 - root_mean_squared_error: 0.1740 - val_loss: 0.2187 - val_mse: 0.0109 - val_mae: 0.0666 - val_root_mean_squared_error: 0.1044 - lr: 7.0000e-05
# Epoch 66/300
# 814/814 [==============================] - 9s 11ms/step - loss: 0.2364 - mse: 0.0299 - mae: 0.0989 - root_mean_squared_error: 0.1728 - val_loss: 0.2166 - val_mse: 0.0115 - val_mae: 0.0696 - val_root_mean_squared_error: 0.1073 - lr: 7.0000e-05
# Epoch 67/300
# 814/814 [==============================] - 11s 14ms/step - loss: 0.2330 - mse: 0.0290 - mae: 0.0979 - root_mean_squared_error: 0.1702 - val_loss: 0.2414 - val_mse: 0.0393 - val_mae: 0.1460 - val_root_mean_squared_error: 0.1983 - lr: 7.0000e-05
# Epoch 68/300
# 814/814 [==============================] - 10s 12ms/step - loss: 0.2308 - mse: 0.0293 - mae: 0.0991 - root_mean_squared_error: 0.1712 - val_loss: 0.2241 - val_mse: 0.0243 - val_mae: 0.1075 - val_root_mean_squared_error: 0.1558 - lr: 7.0000e-05
# Epoch 69/300
# 813/814 [============================>.] - ETA: 0s - loss: 0.2273 - mse: 0.0281 - mae: 0.0965 - root_mean_squared_error: 0.1677
# Epoch 69: ReduceLROnPlateau reducing learning rate to 4.899999621557071e-05.
# 814/814 [==============================] - 8s 9ms/step - loss: 0.2273 - mse: 0.0281 - mae: 0.0965 - root_mean_squared_error: 0.1677 - val_loss: 0.2387 - val_mse: 0.0413 - val_mae: 0.1481 - val_root_mean_squared_error: 0.2033 - lr: 7.0000e-05
# Epoch 70/300
# 814/814 [==============================] - 6s 7ms/step - loss: 0.2234 - mse: 0.0263 - mae: 0.0918 - root_mean_squared_error: 0.1621 - val_loss: 0.2232 - val_mse: 0.0275 - val_mae: 0.1163 - val_root_mean_squared_error: 0.1658 - lr: 4.9000e-05
# Epoch 71/300
# 814/814 [==============================] - 6s 8ms/step - loss: 0.2217 - mse: 0.0264 - mae: 0.0924 - root_mean_squared_error: 0.1626 - val_loss: 0.2427 - val_mse: 0.0492 - val_mae: 0.1615 - val_root_mean_squared_error: 0.2218 - lr: 4.9000e-05
# Epoch 72/300
# 814/814 [==============================] - 9s 11ms/step - loss: 0.2196 - mse: 0.0263 - mae: 0.0921 - root_mean_squared_error: 0.1621 - val_loss: 0.2141 - val_mse: 0.0222 - val_mae: 0.1032 - val_root_mean_squared_error: 0.1489 - lr: 4.9000e-05
# Epoch 73/300
# 814/814 [==============================] - 5s 7ms/step - loss: 0.2170 - mse: 0.0257 - mae: 0.0911 - root_mean_squared_error: 0.1602 - val_loss: 0.2026 - val_mse: 0.0124 - val_mae: 0.0728 - val_root_mean_squared_error: 0.1114 - lr: 4.9000e-05
# Epoch 74/300
# 814/814 [==============================] - 6s 8ms/step - loss: 0.2149 - mse: 0.0255 - mae: 0.0907 - root_mean_squared_error: 0.1596 - val_loss: 0.2152 - val_mse: 0.0272 - val_mae: 0.1158 - val_root_mean_squared_error: 0.1649 - lr: 4.9000e-05
# Epoch 75/300
# 814/814 [==============================] - 7s 8ms/step - loss: 0.2125 - mse: 0.0249 - mae: 0.0899 - root_mean_squared_error: 0.1579 - val_loss: 0.2095 - val_mse: 0.0233 - val_mae: 0.1062 - val_root_mean_squared_error: 0.1527 - lr: 4.9000e-05
# Epoch 76/300
# 808/814 [============================>.] - ETA: 0s - loss: 0.2107 - mse: 0.0249 - mae: 0.0899 - root_mean_squared_error: 0.1580
# Epoch 76: ReduceLROnPlateau reducing learning rate to 3.4299996332265434e-05.
# 814/814 [==============================] - 6s 7ms/step - loss: 0.2107 - mse: 0.0250 - mae: 0.0899 - root_mean_squared_error: 0.1580 - val_loss: 0.2062 - val_mse: 0.0217 - val_mae: 0.1012 - val_root_mean_squared_error: 0.1473 - lr: 4.9000e-05
# Epoch 77/300
# 814/814 [==============================] - 6s 7ms/step - loss: 0.2081 - mse: 0.0238 - mae: 0.0869 - root_mean_squared_error: 0.1544 - val_loss: 0.1971 - val_mse: 0.0138 - val_mae: 0.0777 - val_root_mean_squared_error: 0.1175 - lr: 3.4300e-05
# Epoch 78/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.2065 - mse: 0.0237 - mae: 0.0864 - root_mean_squared_error: 0.1540 - val_loss: 0.2146 - val_mse: 0.0330 - val_mae: 0.1301 - val_root_mean_squared_error: 0.1817 - lr: 3.4300e-05
# Epoch 79/300
# 814/814 [==============================] - 6s 7ms/step - loss: 0.2051 - mse: 0.0237 - mae: 0.0866 - root_mean_squared_error: 0.1540 - val_loss: 0.2166 - val_mse: 0.0365 - val_mae: 0.1389 - val_root_mean_squared_error: 0.1911 - lr: 3.4300e-05
# Epoch 80/300
# 808/814 [============================>.] - ETA: 0s - loss: 0.2035 - mse: 0.0235 - mae: 0.0867 - root_mean_squared_error: 0.1534
# Epoch 80: ReduceLROnPlateau reducing learning rate to 2.400999692326877e-05.
# 814/814 [==============================] - 6s 8ms/step - loss: 0.2035 - mse: 0.0235 - mae: 0.0867 - root_mean_squared_error: 0.1534 - val_loss: 0.2032 - val_mse: 0.0244 - val_mae: 0.1108 - val_root_mean_squared_error: 0.1563 - lr: 3.4300e-05
# Epoch 81/300
# 814/814 [==============================] - 8s 10ms/step - loss: 0.2014 - mse: 0.0227 - mae: 0.0838 - root_mean_squared_error: 0.1505 - val_loss: 0.2081 - val_mse: 0.0304 - val_mae: 0.1258 - val_root_mean_squared_error: 0.1743 - lr: 2.4010e-05
# Epoch 82/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.2002 - mse: 0.0226 - mae: 0.0842 - root_mean_squared_error: 0.1504 - val_loss: 0.2016 - val_mse: 0.0251 - val_mae: 0.1123 - val_root_mean_squared_error: 0.1583 - lr: 2.4010e-05
# Epoch 83/300
# 814/814 [==============================] - 6s 8ms/step - loss: 0.1988 - mse: 0.0224 - mae: 0.0837 - root_mean_squared_error: 0.1496 - val_loss: 0.1901 - val_mse: 0.0145 - val_mae: 0.0813 - val_root_mean_squared_error: 0.1205 - lr: 2.4010e-05
# Epoch 84/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.1972 - mse: 0.0220 - mae: 0.0836 - root_mean_squared_error: 0.1482 - val_loss: 0.2056 - val_mse: 0.0314 - val_mae: 0.1288 - val_root_mean_squared_error: 0.1772 - lr: 2.4010e-05
# Epoch 85/300
# 814/814 [==============================] - 6s 7ms/step - loss: 0.1961 - mse: 0.0220 - mae: 0.0833 - root_mean_squared_error: 0.1483 - val_loss: 0.1974 - val_mse: 0.0242 - val_mae: 0.1107 - val_root_mean_squared_error: 0.1556 - lr: 2.4010e-05
# Epoch 86/300
# 812/814 [============================>.] - ETA: 0s - loss: 0.1949 - mse: 0.0219 - mae: 0.0828 - root_mean_squared_error: 0.1480
# Epoch 86: ReduceLROnPlateau reducing learning rate to 1.6806997336971108e-05.
# 814/814 [==============================] - 6s 7ms/step - loss: 0.1949 - mse: 0.0219 - mae: 0.0828 - root_mean_squared_error: 0.1481 - val_loss: 0.2004 - val_mse: 0.0284 - val_mae: 0.1219 - val_root_mean_squared_error: 0.1686 - lr: 2.4010e-05
# Epoch 87/300
# 814/814 [==============================] - 5s 6ms/step - loss: 0.1932 - mse: 0.0211 - mae: 0.0812 - root_mean_squared_error: 0.1454 - val_loss: 0.1942 - val_mse: 0.0231 - val_mae: 0.1080 - val_root_mean_squared_error: 0.1518 - lr: 1.6807e-05
# Epoch 88/300
# 814/814 [==============================] - 6s 8ms/step - loss: 0.1925 - mse: 0.0213 - mae: 0.0813 - root_mean_squared_error: 0.1461 - val_loss: 0.1974 - val_mse: 0.0272 - val_mae: 0.1189 - val_root_mean_squared_error: 0.1648 - lr: 1.6807e-05
# Epoch 89/300
# 808/814 [============================>.] - ETA: 0s - loss: 0.1913 - mse: 0.0211 - mae: 0.0814 - root_mean_squared_error: 0.1454
# Epoch 89: ReduceLROnPlateau reducing learning rate to 1.1764897499233484e-05.
# Restoring model weights from the end of the best epoch: 83.
# 814/814 [==============================] - 7s 8ms/step - loss: 0.1913 - mse: 0.0211 - mae: 0.0814 - root_mean_squared_error: 0.1453 - val_loss: 0.1902 - val_mse: 0.0208 - val_mae: 0.1023 - val_root_mean_squared_error: 0.1442 - lr: 1.6807e-05
# Epoch 89: early stopping

# %%
GM4TrainHistDf = pd.DataFrame(gm4_TrainHistory.history)
GM4TrainHistDf.plot(figsize=(12,15), logy=True, logx=True)
plt.grid(True)
plt.gca().set_ylim(0,GM4TrainHistDf.values.max())
plt.show()
# Out:
# <ipython-input-82-847365420a85>:4: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.gca().set_ylim(0,GM4TrainHistDf.values.max())

# %% [markdown]
# ## Testing

# %%
GM4.evaluate(gm4_ds_test)
# Out:
# 217/217 [==============================] - 85s 355ms/step - loss: 0.1901 - mse: 0.0144 - mae: 0.0812 - root_mean_squared_error: 0.1201
# [0.19005776941776276,
#  0.014429607428610325,
#  0.0811816081404686,
#  0.12012328952550888]

# %%
n_print = 20

for (xs, ys) in gm4_ds_test.take(1):
  preds = GM4.predict(xs)
  for i in range(n_print):
    # print("Inputs: {}".format(xs[i]))
    print("True: {} | Pred: {}".format(ys[i], preds[i]))
    # print("-"*10)
# Out:
# 16/16 [==============================] - 0s 6ms/step
# True: [75.72020 14.32994 13.75370 158.39192 89.87608] | Pred: [75.74963 14.31803 13.70699 158.36661 89.75412]
# True: [76.57415 14.63953 13.51247 160.14769 91.81081] | Pred: [76.54461 14.63764 13.50024 160.07422 91.74326]
# True: [77.74349 17.51965 12.08437 166.14223 109.86436] | Pred: [77.70522 17.48067 12.04774 166.06409 109.65540]
# True: [84.10329 20.81759 10.31771 182.47343 130.51572] | Pred: [84.12168 20.79859 10.14742 182.53313 130.39037]
# True: [93.15348 18.84914 10.52878 196.28143 118.24932] | Pred: [93.08242 18.85363 10.59016 195.92387 118.24250]
# True: [78.66270 16.31707 12.55920 166.25690 102.32088] | Pred: [78.75776 16.29797 12.49713 166.33781 102.20159]
# True: [87.79626 20.11898 10.26818 188.13263 126.15954] | Pred: [87.69550 20.12198 10.26048 188.03358 126.15898]
# True: [88.68123 18.71159 10.69448 187.82899 117.34405] | Pred: [88.43169 18.72760 10.76686 187.19667 117.42237]
# True: [70.56181 14.34678 14.16902 149.20161 89.97892] | Pred: [70.39469 14.37205 14.08965 149.03331 90.15141]
# True: [78.74072 17.09014 12.22572 167.22864 107.18098] | Pred: [78.56272 17.06684 12.23653 167.01100 106.99218]
# True: [75.79441 14.59115 13.62136 158.59900 91.51260] | Pred: [75.70966 14.61206 13.58726 158.35994 91.51463]
# True: [77.23532 14.15969 13.70180 160.69946 88.81138] | Pred: [77.09885 14.16499 13.71648 160.44054 88.79692]
# True: [79.47050 14.34824 13.37312 164.98004 89.99711] | Pred: [79.34209 14.34359 13.38315 164.73570 89.95669]
# True: [75.45175 14.61970 13.59951 159.01273 91.69417] | Pred: [75.37536 14.59894 13.67091 158.66795 91.60075]
# True: [80.76617 15.51192 12.76017 169.00751 97.28886] | Pred: [80.57001 15.49488 12.79420 168.61159 97.17405]
# True: [75.49097 14.84929 13.50950 158.50824 93.12478] | Pred: [75.45441 14.84790 13.46812 158.35896 93.05807]
# True: [71.06577 15.81778 13.32103 152.16188 99.18632] | Pred: [71.11170 15.81193 13.33179 152.19708 99.16405]
# True: [78.23444 16.52359 12.34414 165.56725 103.61461] | Pred: [78.13457 16.52374 12.35628 165.45026 103.62615]
# True: [74.30168 15.48911 13.26963 157.42583 97.13379] | Pred: [74.16500 15.48862 13.26953 157.22511 97.12296]
# True: [70.73370 14.74498 13.92064 149.88715 92.46515] | Pred: [70.65252 14.74236 13.85440 149.77550 92.45479]

# %%
scatter_accuracy(ys, preds)

# %%
GM4.save(gm4_best_save)
GM4.save_weights(gm4_best_save_weights)
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <__main__.ResnetBlock object at 0x7f9ddc80e3a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <__main__.ResnetBlock object at 0x7f9ddc5c97f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f9ddc5c9460>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f9ddc5c9670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f9ddc5c9130>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.regularization.dropout.Dropout object at 0x7f9ddc62eeb0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f9ddc858a90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f9ddc57aac0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f9ddc57af10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.regularization.dropout.Dropout object at 0x7f9ddc5c2c10>, because it is not built.
# WARNING:absl:Found untraced functions such as call, call while saving (showing 2 of 2). These functions will not be directly callable after loading.

# %%
GM4TrainHistDf.to_csv(gm4_save_root/"train_hist.csv")
