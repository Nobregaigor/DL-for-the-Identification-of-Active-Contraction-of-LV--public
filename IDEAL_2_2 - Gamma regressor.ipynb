# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import os
import pathlib
import matplotlib.pyplot as plt
import matplotlib
from tensorflow.keras import layers

# %% [markdown]
# ## formatting

# %%
float_formatter = "{:.5f}".format
np.set_printoptions(formatter={'float_kind':float_formatter})

plt.style.use('default')
# %matplotlib inline

matplotlib.rcParams.update({'font.size': 10})

# %% [markdown]
# ## Paths and directories

# %%
ROOT_DIR = pathlib.Path("/content/drive/MyDrive/Research/PAPER_1_CODE")
DATA_DIR = ROOT_DIR/"geometrics_ideal_clean"

csv_header_filepath = DATA_DIR/"header.json"

train_dir = DATA_DIR/"train"
valid_dir = DATA_DIR/"valid"
test_dir = DATA_DIR/"test"

model_save_root = ROOT_DIR/"models"

# %%
csv_header_filepath
# Out:
# PosixPath('/content/drive/MyDrive/Research/PAPER_1_CODE/geometrics_ideal_clean/header.json')

# %%
import json
with open(csv_header_filepath, "r") as jsonfile:
  jsondata = json.load(jsonfile)
header = jsondata["headers"]

# %% [markdown]
# # Utils

# %% [markdown]
# ## Modules

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense

class ResnetBlock(tf.keras.Model):
  def __init__(self, units, dropout_rate=0.001, **kwargs):
    super(ResnetBlock, self).__init__(**kwargs)

    self.units=units
    self.dropout_rate=dropout_rate
    self.dense1 = Dense(units)
    self.dense2 = Dense(units)
    self.dense3 = Dense(units)

    self.dropout = Dropout(dropout_rate)
  
  @tf.function()
  def call(self, input_tensor, training=False):
    x = self.dense1(input_tensor, training=training)
    x = self.dropout(x)
    x = self.dense2(x, training=training)
    x = self.dropout(x)
    x = self.dense3(x, training=training)
    x = self.dropout(x)

    x += input_tensor
    return tf.nn.relu(x)
  
  def get_config(self):
      config = super(ResnetBlock, self).get_config()
      config.update({"units": self.units, "dropout_rate": self.dropout_rate})
      return config

# %%
import tensorflow as tf

class NormalizedBaseClass(tf.keras.losses.Loss):
  def __init__(self, lb=[], up=[], indices=[], epsilon=1e-12, dtype=tf.float32, **kwargs):
    super().__init__(**kwargs)

    self.indices = indices
    self.use_indices = True if len(indices) > 0 else False

    self.epsilon = epsilon
    self.dtype = dtype

    self.lowBound = self.setBounds(lb)
    self.uppBound = self.setBounds(up)
    self.epsilon_tensor = self.setEpsilonTensor(epsilon)
    
    self._dividion_denomiator = tf.maximum(tf.subtract(self.uppBound, self.lowBound, name="denom_sub"), self.epsilon_tensor)    
  
  def setBounds(self, bd):
    return tf.constant(self.gather(bd), dtype=self.dtype)
  
  def setEpsilonTensor(self,epsilon):
    return tf.constant(self.epsilon, dtype=self.dtype, shape=self.lowBound.shape)

  def gather(self, tensor, axis=-1):
    if not self.use_indices:
      return tensor
    gathered = tf.gather(tensor, self.indices, axis=axis)
    if gathered.dtype != self.dtype:
      gathered = tf.cast(gathered, self.dtype)
    return gathered

  def normalize(self, X, gather_x=True):
    if gather_x:
      X = self.gather(X)
    S = tf.subtract(X, self.lowBound, name="norm_sub")
    return tf.divide(S, self._dividion_denomiator, name="norm_div")
  
  def convert_inputs(self, y_true, y_pred, set_dtype=True):
    y_pred = tf.convert_to_tensor(y_pred)    
    y_true = tf.cast(y_true, y_pred.dtype)
    if set_dtype:
      self.setDtype(y_pred.dtype)
    return y_true, y_pred

  def setDtype(self, dtype):
    self.dtype = dtype

  def get_config(self):
    base_config = super().get_config()
    return {**base_config, "lb":self.lb, "up": self.up, "epsilon": self.epsilon}
  
class NormalizedMeanAbsoluteError(NormalizedBaseClass):
  def __init__(self, lb=[], up=[], indices=[], **kwargs):
    super().__init__(**kwargs)
  
  def call(self, y_true, y_pred):
    y_true, y_pred = self.convert_inputs(y_true, y_pred)
    y_true_norm, y_pred_norm = self.normalize(y_true), self.normalize(y_pred, False)
    return tf.math.reduce_mean(tf.abs(y_pred_norm - y_true_norm), axis=-1)
  def get_config(self):
    base_config = super().get_config()
    return {**base_config, "lb":self.lb, "up": self.up, "epsilon": self.epsilon}

class NormalizedMeanSquaredError(NormalizedBaseClass):
  def __init__(self, **kwargs):
    super().__init__(**kwargs)
  
  def call(self, y_true, y_pred):
    y_true, y_pred = self.convert_inputs(y_true, y_pred)
    y_true_norm, y_pred_norm = self.normalize(y_true), self.normalize(y_pred, False)
    return tf.math.reduce_mean(tf.math.square(y_pred_norm - y_true_norm), axis=-1)
  def get_config(self):
    base_config = super().get_config()
    return {**base_config, "lb":self.lb, "up": self.up, "epsilon": self.epsilon}

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense

def build_norm_layer(batch_size, header, labels, feats, name="norm",int_labels=False):
  from tensorflow.keras.layers.experimental import preprocessing
  ds_norm  = csv_ds_reader(train_dir, header, labels, feats, int_labels=int_labels, batch_size=batch_size)
  norm_layer = preprocessing.Normalization(name=name)
  for (xs, _) in ds_norm.take(1):
    norm_layer.adapt(xs)
  return norm_layer

class GAMMA_Regressor_Model(tf.keras.Model):
  def __init__(self, n_units, n_blocks, norm_layer, n_output_labels, **kwargs):
    super(GAMMA_Regressor_Model, self).__init__(**kwargs)

    self.n_units = n_units
    self.n_blocks = n_blocks
    self.norm = norm_layer

    self.d1 = Dense(self.n_units, activation="relu")
    self.l1 = [ResnetBlock(self.n_units, dropout_rate=0.001) for _ in range(n_blocks)]
    self.l2 = [ResnetBlock(self.n_units*2, dropout_rate=0.001) for _ in range(n_blocks)]
    self.l3 = [ResnetBlock(self.n_units*4, dropout_rate=0.001) for _ in range(n_blocks)]

    self.d2 = Dense(self.n_units*2, activation="relu")
    self.d3 = Dense(self.n_units*4, activation="relu")

    self.tail = [
      layers.ActivityRegularization(0.0001, 0.0001),
      Dense(n_output_labels, name="gr_body_out"),
    ]

  def call(self, input_tensor, training=False):
    x_norm = self.norm(input_tensor)
    # x = tf.concat([x_norm, x_bins], axis=1)
    x = self.d1(x_norm)
    for layer in self.l1:
      x = layer(x)
    x = self.d2(x)
    x = self.d3(x)
    for layer in self.tail:
      x = layer(x)
    return x

  def get_config(self):
      # config = super(CM4_Model, self).get_config()
      return {"n_units": self.n_units, "n_blocks": self.n_blocks}

# %% [markdown]
# ## utils

# %%
import json
import pandas as pd
import numpy as np
import tensorflow as tf

def get_indexes(header, of_keys):
  return [header[key]+1 for key in of_keys]

def csv_ds_reader(filepaths, 
                  header,
                  label_keys,
                  feature_keys,
                  int_labels=False,
                  reshape_to=None,
                  batch_size=32,
    repeat=1, n_readers=5, 
    shuffle_buffer_size=10000, 
    cache=True, 
    n_read_threads=None, 
    n_parse_threads=5):
  
  label_indexes = get_indexes(header, label_keys)
  feature_indexes = get_indexes(header, feature_keys)
  
  def get_features_labels(line):
    """
      Re-structures DS to read csv field and return 'features, labels'
    """
    defs = [0.] * (len(header) + 1) #n_labels
    fields = tf.io.decode_csv(line, record_defaults=defs)
 
    # cm-lookup -> CM1 -> (CMs), (FB, PV)
    _labels  = tf.stack([fields[i] for i in label_indexes])
    features = tf.stack([fields[i] for i in feature_indexes])
   
    try:
      tf.debugging.check_numerics(_labels, message='Checking _labels')
    except Exception as e:
      assert "Checking labels: Tensor had NaN values" in e.message
    
    try:
      tf.debugging.check_numerics(features, message='Checking features')
    except Exception as e:
      assert "Checking features: Tensor had NaN values" in e.message

    if int_labels is True:
      _labels = tf.cast(_labels, tf.int32, "label_int")

    if reshape_to is not None:
      _labels = tf.reshape(_labels, reshape_to)
  
    return features, _labels
  
  # get files
  ds = tf.data.Dataset.list_files(str(pathlib.Path(filepaths)/'*.csv'))
  # read in random order cycling through files
  ds = ds.interleave(
      lambda filepath: tf.data.TextLineDataset(filepath).skip(1),
      cycle_length=n_readers, num_parallel_calls=n_read_threads
  )
  # shuffle and repeat
  ds = ds.shuffle(shuffle_buffer_size).repeat(repeat)
  # preprocess dataset (must provide a function)
  ds = ds.map(get_features_labels, num_parallel_calls=n_parse_threads)
  # cache dataset
  ds = ds.cache()
  ds = ds.batch(batch_size)
  ds = ds.prefetch(1)
  return ds

# %%
import json
def save_model_info(dir, features, labels, scales=[]):
  model_info = {"features": features, "labels": labels, "scales": scales}
  model_info = json.dumps(model_info)
  if not os.path.exists(dir):
    os.makedirs(dir)
  with open(dir/"info.json", "w") as jsonfile:
    jsonfile.write(model_info)

# %%
import tensorflow as tf
import matplotlib 
import matplotlib.pyplot as plt

def scatter_accuracy(ys, preds):
  try:
    if ys.shape != preds.shape:
      ys = tf.reshape(ys, preds.shape)
    e = abs(ys - preds)
    fig, ax = plt.subplots(figsize=(10,10))
    cb = ax.scatter(ys, preds, c=e, cmap="jet")
    ax.grid()
    ax.set_ylabel("Predicted")
    ax.set_xlabel("True")
    ax.set_title("Accuracy scatter plot")
    fig.colorbar(cb, ax=ax)
  except:
    print("Failed generating scatter plot.")

# %% [markdown]
# # Model features and labels

# %%
MODEL_PREFIX = "IDEAL_GAMMA_REGRESSOR"

# %%
FEATS = ["endo", "epi", "pressure", "volume"]
LABELS = ["gamma",]
BIN_LABELS = [k + "-b" for k in FEATS if k+"-b" in header.keys()]
FEATS, BIN_LABELS, LABELS
# Out:
# (['endo', 'epi', 'pressure', 'volume'],
#  ['endo-b', 'epi-b', 'pressure-b', 'volume-b'],
#  ['gamma'])

# %% [markdown]
# # Gamma Regressor with 4 inputs

# %%
gm4_save_root = model_save_root/MODEL_PREFIX.upper()
gm4_best_save = gm4_save_root/"best"
gm4_best_save_weights = gm4_best_save/"weights"

# %% [markdown]
# ## Load Gamma Dataset
#
# Labels: ['gamma']
#
# Features: ['epi', 'endo', 'pressure', 'volume']

# %%
BATCH_SIZE = 500
gm4_ds_train = csv_ds_reader(train_dir, header, LABELS, FEATS, batch_size=BATCH_SIZE)
gm4_ds_valid = csv_ds_reader(valid_dir, header, LABELS, FEATS, batch_size=BATCH_SIZE)
gm4_ds_test  = csv_ds_reader(test_dir,  header, LABELS, FEATS, batch_size=BATCH_SIZE)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
LABELS
# Out:
# ['gamma']

# %%
print("CM4 train set:")
for (features, labels) in gm4_ds_train.take(1):
  print("Features: {} \nLabels: {}".format(features[0], labels[0]))
  print("Shapes -> Features: {}, Labels: {}".format(features.shape, labels.shape))
# Out:
# CM4 train set:
# Features: [74.00000 -70.00000 0.55000 0.92772]
# Labels: [0.13800]
# Shapes -> Features: (500, 4), Labels: (500, 1)

# %% [markdown]
# ### Normalization Layer

# %%
GAMMA_NormLayer = build_norm_layer(1000, header, LABELS, FEATS, MODEL_PREFIX+"_norm")

# %% [markdown]
# ### Arquitecture

# %%
GAMMA_R = GAMMA_Regressor_Model(50, 1, GAMMA_NormLayer, len(LABELS))
GAMMA_R.build([None, len(FEATS)])
GAMMA_R.summary()
# Out:
# Model: "gamma__regressor__model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  IDEAL_GAMMA_REGRESSOR_norm   multiple                 9
#  (Normalization)
#
#  dense_12 (Dense)            multiple                  250
#
#  resnet_block_3 (ResnetBlock  multiple                 7650
#  )
#
#  resnet_block_4 (ResnetBlock  multiple                 0 (unused)
#  )
#
#  resnet_block_5 (ResnetBlock  multiple                 0 (unused)
#  )
#
#  dense_22 (Dense)            multiple                  5100
#
#  dense_23 (Dense)            multiple                  20200
#
#  activity_regularization_1 (  multiple                 0
#  ActivityRegularization)
#
#  gr_body_out (Dense)         multiple                  201
#
# =================================================================
# Total params: 33,410
# Trainable params: 33,401
# Non-trainable params: 9
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
initial_learning_rate = 1e-4
GAMMA_ROptimizer = tf.keras.optimizers.Adam(learning_rate=initial_learning_rate)
GAMMA_RLoss = tf.keras.losses.MeanSquaredError()
GAMMA_R.compile(
    loss = [GAMMA_RLoss],# tf.keras.losses.MeanSquaredLogarithmicError()],
    optimizer=GAMMA_ROptimizer,
    metrics=["mse", "mae", tf.keras.metrics.RootMeanSquaredError()]
)

# %%
GAMMA_RCallbacks = [
  tf.keras.callbacks.ReduceLROnPlateau(factor=0.7, patience=3, verbose=1),
  tf.keras.callbacks.EarlyStopping(patience=6, verbose=1, restore_best_weights=True),
]

# %%
with tf.device('/device:GPU:0'):
  gm4_TrainHistory = GAMMA_R.fit(
    gm4_ds_train,
    epochs=300, verbose=1, 
    validation_data=gm4_ds_valid,
    callbacks=GAMMA_RCallbacks
  )
# Out:
# Epoch 1/300
# 814/814 [==============================] - 148s 175ms/step - loss: 0.0016 - mse: 8.6935e-04 - mae: 0.0180 - root_mean_squared_error: 0.0295 - val_loss: 4.7808e-04 - val_mse: 8.7059e-05 - val_mae: 0.0070 - val_root_mean_squared_error: 0.0093 - lr: 1.0000e-04
# Epoch 2/300
# 814/814 [==============================] - 5s 6ms/step - loss: 3.3944e-04 - mse: 7.6961e-05 - mae: 0.0063 - root_mean_squared_error: 0.0088 - val_loss: 2.2917e-04 - val_mse: 4.1611e-05 - val_mae: 0.0048 - val_root_mean_squared_error: 0.0065 - lr: 1.0000e-04
# Epoch 3/300
# 814/814 [==============================] - 6s 7ms/step - loss: 2.0361e-04 - mse: 4.3621e-05 - mae: 0.0047 - root_mean_squared_error: 0.0066 - val_loss: 1.6218e-04 - val_mse: 2.3956e-05 - val_mae: 0.0037 - val_root_mean_squared_error: 0.0049 - lr: 1.0000e-04
# Epoch 4/300
# 814/814 [==============================] - 5s 7ms/step - loss: 1.5120e-04 - mse: 2.8373e-05 - mae: 0.0037 - root_mean_squared_error: 0.0053 - val_loss: 1.2441e-04 - val_mse: 1.6745e-05 - val_mae: 0.0030 - val_root_mean_squared_error: 0.0041 - lr: 1.0000e-04
# Epoch 5/300
# 814/814 [==============================] - 5s 6ms/step - loss: 1.1578e-04 - mse: 2.0727e-05 - mae: 0.0032 - root_mean_squared_error: 0.0046 - val_loss: 9.5391e-05 - val_mse: 1.2796e-05 - val_mae: 0.0027 - val_root_mean_squared_error: 0.0036 - lr: 1.0000e-04
# Epoch 6/300
# 814/814 [==============================] - 6s 7ms/step - loss: 8.8994e-05 - mse: 1.6026e-05 - mae: 0.0028 - root_mean_squared_error: 0.0040 - val_loss: 7.3182e-05 - val_mse: 9.6195e-06 - val_mae: 0.0023 - val_root_mean_squared_error: 0.0031 - lr: 1.0000e-04
# Epoch 7/300
# 805/814 [============================>.] - ETA: 0s - loss: 6.9541e-05 - mse: 1.2935e-05 - mae: 0.0024 - root_mean_squared_error: 0.0036
# Epoch 7: ReduceLROnPlateau reducing learning rate to 6.999999823165126e-05.
# 814/814 [==============================] - 5s 6ms/step - loss: 6.9464e-05 - mse: 1.2931e-05 - mae: 0.0024 - root_mean_squared_error: 0.0036 - val_loss: 5.7361e-05 - val_mse: 7.6347e-06 - val_mae: 0.0020 - val_root_mean_squared_error: 0.0028 - lr: 1.0000e-04
# Epoch 8/300
# 814/814 [==============================] - 7s 8ms/step - loss: 5.6877e-05 - mse: 1.1028e-05 - mae: 0.0022 - root_mean_squared_error: 0.0033 - val_loss: 4.8910e-05 - val_mse: 7.2999e-06 - val_mae: 0.0019 - val_root_mean_squared_error: 0.0027 - lr: 7.0000e-05
# Epoch 9/300
# 814/814 [==============================] - 6s 7ms/step - loss: 4.8002e-05 - mse: 9.7996e-06 - mae: 0.0020 - root_mean_squared_error: 0.0031 - val_loss: 4.1119e-05 - val_mse: 6.6854e-06 - val_mae: 0.0017 - val_root_mean_squared_error: 0.0026 - lr: 7.0000e-05
# Epoch 10/300
# 814/814 [==============================] - ETA: 0s - loss: 4.0483e-05 - mse: 8.8199e-06 - mae: 0.0019 - root_mean_squared_error: 0.0030
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.899999621557071e-05.
# 814/814 [==============================] - 6s 8ms/step - loss: 4.0483e-05 - mse: 8.8199e-06 - mae: 0.0019 - root_mean_squared_error: 0.0030 - val_loss: 3.3937e-05 - val_mse: 5.1758e-06 - val_mae: 0.0016 - val_root_mean_squared_error: 0.0023 - lr: 7.0000e-05
# Epoch 11/300
# 814/814 [==============================] - 5s 6ms/step - loss: 3.5211e-05 - mse: 8.0870e-06 - mae: 0.0018 - root_mean_squared_error: 0.0028 - val_loss: 3.0354e-05 - val_mse: 5.0822e-06 - val_mae: 0.0016 - val_root_mean_squared_error: 0.0023 - lr: 4.9000e-05
# Epoch 12/300
# 814/814 [==============================] - 6s 7ms/step - loss: 3.1519e-05 - mse: 7.4784e-06 - mae: 0.0017 - root_mean_squared_error: 0.0027 - val_loss: 2.7375e-05 - val_mse: 4.8266e-06 - val_mae: 0.0015 - val_root_mean_squared_error: 0.0022 - lr: 4.9000e-05
# Epoch 13/300
# 808/814 [============================>.] - ETA: 0s - loss: 2.8860e-05 - mse: 7.1832e-06 - mae: 0.0017 - root_mean_squared_error: 0.0027
# Epoch 13: ReduceLROnPlateau reducing learning rate to 3.4299996332265434e-05.
# 814/814 [==============================] - 5s 6ms/step - loss: 2.8847e-05 - mse: 7.1769e-06 - mae: 0.0017 - root_mean_squared_error: 0.0027 - val_loss: 2.4948e-05 - val_mse: 4.3721e-06 - val_mae: 0.0014 - val_root_mean_squared_error: 0.0021 - lr: 4.9000e-05
# Epoch 14/300
# 814/814 [==============================] - 5s 6ms/step - loss: 2.6756e-05 - mse: 6.6448e-06 - mae: 0.0016 - root_mean_squared_error: 0.0026 - val_loss: 2.3551e-05 - val_mse: 4.1604e-06 - val_mae: 0.0014 - val_root_mean_squared_error: 0.0020 - lr: 3.4300e-05
# Epoch 15/300
# 814/814 [==============================] - 6s 8ms/step - loss: 2.5488e-05 - mse: 6.4380e-06 - mae: 0.0016 - root_mean_squared_error: 0.0025 - val_loss: 2.2425e-05 - val_mse: 3.9909e-06 - val_mae: 0.0013 - val_root_mean_squared_error: 0.0020 - lr: 3.4300e-05
# Epoch 16/300
# 814/814 [==============================] - 5s 7ms/step - loss: 2.4304e-05 - mse: 6.1357e-06 - mae: 0.0015 - root_mean_squared_error: 0.0025 - val_loss: 2.1373e-05 - val_mse: 3.6876e-06 - val_mae: 0.0013 - val_root_mean_squared_error: 0.0019 - lr: 3.4300e-05
# Epoch 17/300
# 811/814 [============================>.] - ETA: 0s - loss: 2.3288e-05 - mse: 5.8922e-06 - mae: 0.0015 - root_mean_squared_error: 0.0024
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.400999692326877e-05.
# 814/814 [==============================] - 6s 8ms/step - loss: 2.3285e-05 - mse: 5.8901e-06 - mae: 0.0015 - root_mean_squared_error: 0.0024 - val_loss: 2.0588e-05 - val_mse: 3.5522e-06 - val_mae: 0.0013 - val_root_mean_squared_error: 0.0019 - lr: 3.4300e-05
# Epoch 18/300
# 814/814 [==============================] - 5s 6ms/step - loss: 2.2401e-05 - mse: 5.5866e-06 - mae: 0.0015 - root_mean_squared_error: 0.0024 - val_loss: 1.9981e-05 - val_mse: 3.4581e-06 - val_mae: 0.0013 - val_root_mean_squared_error: 0.0019 - lr: 2.4010e-05
# Epoch 19/300
# 814/814 [==============================] - 6s 8ms/step - loss: 2.1882e-05 - mse: 5.5232e-06 - mae: 0.0015 - root_mean_squared_error: 0.0024 - val_loss: 1.9520e-05 - val_mse: 3.5227e-06 - val_mae: 0.0012 - val_root_mean_squared_error: 0.0019 - lr: 2.4010e-05
# Epoch 20/300
# 808/814 [============================>.] - ETA: 0s - loss: 2.1230e-05 - mse: 5.3042e-06 - mae: 0.0014 - root_mean_squared_error: 0.0023
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.6806997336971108e-05.
# 814/814 [==============================] - 5s 6ms/step - loss: 2.1229e-05 - mse: 5.3048e-06 - mae: 0.0014 - root_mean_squared_error: 0.0023 - val_loss: 1.8912e-05 - val_mse: 3.2306e-06 - val_mae: 0.0012 - val_root_mean_squared_error: 0.0018 - lr: 2.4010e-05
# Epoch 21/300
# 814/814 [==============================] - 6s 7ms/step - loss: 2.0822e-05 - mse: 5.2471e-06 - mae: 0.0014 - root_mean_squared_error: 0.0023 - val_loss: 1.8630e-05 - val_mse: 3.3022e-06 - val_mae: 0.0012 - val_root_mean_squared_error: 0.0018 - lr: 1.6807e-05
# Epoch 22/300
# 814/814 [==============================] - 5s 7ms/step - loss: 2.0353e-05 - mse: 5.0589e-06 - mae: 0.0014 - root_mean_squared_error: 0.0022 - val_loss: 1.8237e-05 - val_mse: 3.1490e-06 - val_mae: 0.0012 - val_root_mean_squared_error: 0.0018 - lr: 1.6807e-05
# Epoch 23/300
# 810/814 [============================>.] - ETA: 0s - loss: 2.0033e-05 - mse: 5.0037e-06 - mae: 0.0014 - root_mean_squared_error: 0.0022
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.1764897499233484e-05.
# 814/814 [==============================] - 6s 8ms/step - loss: 2.0035e-05 - mse: 5.0065e-06 - mae: 0.0014 - root_mean_squared_error: 0.0022 - val_loss: 1.7957e-05 - val_mse: 3.1555e-06 - val_mae: 0.0012 - val_root_mean_squared_error: 0.0018 - lr: 1.6807e-05
# Epoch 24/300
# 814/814 [==============================] - 6s 7ms/step - loss: 1.9661e-05 - mse: 4.8495e-06 - mae: 0.0014 - root_mean_squared_error: 0.0022 - val_loss: 1.7711e-05 - val_mse: 3.0437e-06 - val_mae: 0.0012 - val_root_mean_squared_error: 0.0017 - lr: 1.1765e-05
# Epoch 25/300
# 814/814 [==============================] - 6s 7ms/step - loss: 1.9427e-05 - mse: 4.7937e-06 - mae: 0.0013 - root_mean_squared_error: 0.0022 - val_loss: 1.7535e-05 - val_mse: 3.0916e-06 - val_mae: 0.0012 - val_root_mean_squared_error: 0.0018 - lr: 1.1765e-05
# Epoch 26/300
# 810/814 [============================>.] - ETA: 0s - loss: 1.9216e-05 - mse: 4.7603e-06 - mae: 0.0013 - root_mean_squared_error: 0.0022
# Epoch 26: ReduceLROnPlateau reducing learning rate to 8.235428504121954e-06.
# 814/814 [==============================] - 5s 6ms/step - loss: 1.9227e-05 - mse: 4.7707e-06 - mae: 0.0013 - root_mean_squared_error: 0.0022 - val_loss: 1.7293e-05 - val_mse: 2.9902e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.1765e-05
# Epoch 27/300
# 814/814 [==============================] - 6s 8ms/step - loss: 1.9003e-05 - mse: 4.6972e-06 - mae: 0.0013 - root_mean_squared_error: 0.0022 - val_loss: 1.7159e-05 - val_mse: 3.0180e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 8.2354e-06
# Epoch 28/300
# 814/814 [==============================] - 8s 10ms/step - loss: 1.8791e-05 - mse: 4.6049e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.7029e-05 - val_mse: 3.0127e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 8.2354e-06
# Epoch 29/300
# 807/814 [============================>.] - ETA: 0s - loss: 1.8654e-05 - mse: 4.5895e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 29: ReduceLROnPlateau reducing learning rate to 5.764799698226852e-06.
# 814/814 [==============================] - 8s 10ms/step - loss: 1.8650e-05 - mse: 4.5866e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6925e-05 - val_mse: 3.0573e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 8.2354e-06
# Epoch 30/300
# 814/814 [==============================] - 6s 7ms/step - loss: 1.8508e-05 - mse: 4.5476e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6787e-05 - val_mse: 2.9738e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 5.7648e-06
# Epoch 31/300
# 814/814 [==============================] - 5s 6ms/step - loss: 1.8406e-05 - mse: 4.5262e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6658e-05 - val_mse: 2.9123e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 5.7648e-06
# Epoch 32/300
# 810/814 [============================>.] - ETA: 0s - loss: 1.8207e-05 - mse: 4.4104e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 32: ReduceLROnPlateau reducing learning rate to 4.035359916088054e-06.
# 814/814 [==============================] - 5s 6ms/step - loss: 1.8206e-05 - mse: 4.4098e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6579e-05 - val_mse: 2.9327e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 5.7648e-06
# Epoch 33/300
# 814/814 [==============================] - 5s 7ms/step - loss: 1.8203e-05 - mse: 4.4749e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6495e-05 - val_mse: 2.8844e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 4.0354e-06
# Epoch 34/300
# 814/814 [==============================] - 5s 6ms/step - loss: 1.8170e-05 - mse: 4.4975e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6419e-05 - val_mse: 2.8564e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 4.0354e-06
# Epoch 35/300
# 809/814 [============================>.] - ETA: 0s - loss: 1.7989e-05 - mse: 4.3788e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 35: ReduceLROnPlateau reducing learning rate to 2.8247518457646947e-06.
# 814/814 [==============================] - 5s 6ms/step - loss: 1.7992e-05 - mse: 4.3820e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6372e-05 - val_mse: 2.8859e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 4.0354e-06
# Epoch 36/300
# 814/814 [==============================] - 6s 8ms/step - loss: 1.8015e-05 - mse: 4.4514e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6296e-05 - val_mse: 2.8297e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 2.8248e-06
# Epoch 37/300
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7913e-05 - mse: 4.3907e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6249e-05 - val_mse: 2.8130e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 2.8248e-06
# Epoch 38/300
# 813/814 [============================>.] - ETA: 0s - loss: 1.7919e-05 - mse: 4.4366e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.9773262920352863e-06.
# 814/814 [==============================] - 5s 6ms/step - loss: 1.7919e-05 - mse: 4.4360e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6209e-05 - val_mse: 2.8245e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 2.8248e-06
# Epoch 39/300
# 814/814 [==============================] - 6s 8ms/step - loss: 1.7809e-05 - mse: 4.3612e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6175e-05 - val_mse: 2.8191e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.9773e-06
# Epoch 40/300
# 814/814 [==============================] - 7s 8ms/step - loss: 1.7779e-05 - mse: 4.3596e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6141e-05 - val_mse: 2.8052e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.9773e-06
# Epoch 41/300
# 807/814 [============================>.] - ETA: 0s - loss: 1.7706e-05 - mse: 4.3126e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.3841284044247003e-06.
# 814/814 [==============================] - 6s 7ms/step - loss: 1.7706e-05 - mse: 4.3132e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6104e-05 - val_mse: 2.7882e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.9773e-06
# Epoch 42/300
# 814/814 [==============================] - 5s 6ms/step - loss: 1.7779e-05 - mse: 4.4102e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6083e-05 - val_mse: 2.7921e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.3841e-06
# Epoch 43/300
# 814/814 [==============================] - 7s 8ms/step - loss: 1.7718e-05 - mse: 4.3669e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6061e-05 - val_mse: 2.7808e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.3841e-06
# Epoch 44/300
# 813/814 [============================>.] - ETA: 0s - loss: 1.7634e-05 - mse: 4.3058e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 44: ReduceLROnPlateau reducing learning rate to 9.68889867181133e-07.
# 814/814 [==============================] - 13s 16ms/step - loss: 1.7635e-05 - mse: 4.3060e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6046e-05 - val_mse: 2.8118e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.3841e-06
# Epoch 45/300
# 814/814 [==============================] - 7s 9ms/step - loss: 1.7587e-05 - mse: 4.2739e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6024e-05 - val_mse: 2.7949e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 9.6889e-07
# Epoch 46/300
# 814/814 [==============================] - 6s 8ms/step - loss: 1.7649e-05 - mse: 4.3491e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.6021e-05 - val_mse: 2.8157e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 9.6889e-07
# Epoch 47/300
# 806/814 [============================>.] - ETA: 0s - loss: 1.7569e-05 - mse: 4.2826e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.782228751944785e-07.
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7578e-05 - mse: 4.2919e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5998e-05 - val_mse: 2.8010e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 9.6889e-07
# Epoch 48/300
# 814/814 [==============================] - 6s 7ms/step - loss: 1.7539e-05 - mse: 4.2643e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5988e-05 - val_mse: 2.8072e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 6.7822e-07
# Epoch 49/300
# 814/814 [==============================] - 6s 8ms/step - loss: 1.7550e-05 - mse: 4.2850e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5980e-05 - val_mse: 2.8062e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 6.7822e-07
# Epoch 50/300
# 810/814 [============================>.] - ETA: 0s - loss: 1.7602e-05 - mse: 4.3477e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 50: ReduceLROnPlateau reducing learning rate to 4.7475601263613496e-07.
# 814/814 [==============================] - 5s 6ms/step - loss: 1.7600e-05 - mse: 4.3462e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5970e-05 - val_mse: 2.8099e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 6.7822e-07
# Epoch 51/300
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7586e-05 - mse: 4.3392e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5965e-05 - val_mse: 2.8117e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 4.7476e-07
# Epoch 52/300
# 814/814 [==============================] - 6s 8ms/step - loss: 1.7593e-05 - mse: 4.3535e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5956e-05 - val_mse: 2.8106e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 4.7476e-07
# Epoch 53/300
# 806/814 [============================>.] - ETA: 0s - loss: 1.7593e-05 - mse: 4.3594e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 53: ReduceLROnPlateau reducing learning rate to 3.323292048662551e-07.
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7596e-05 - mse: 4.3621e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5939e-05 - val_mse: 2.7908e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 4.7476e-07
# Epoch 54/300
# 814/814 [==============================] - 6s 8ms/step - loss: 1.7556e-05 - mse: 4.3255e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5936e-05 - val_mse: 2.7958e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 3.3233e-07
# Epoch 55/300
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7472e-05 - mse: 4.2479e-06 - mae: 0.0012 - root_mean_squared_error: 0.0021 - val_loss: 1.5935e-05 - val_mse: 2.8011e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 3.3233e-07
# Epoch 56/300
# 812/814 [============================>.] - ETA: 0s - loss: 1.7543e-05 - mse: 4.3252e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 56: ReduceLROnPlateau reducing learning rate to 2.3263043544829997e-07.
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7541e-05 - mse: 4.3230e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5926e-05 - val_mse: 2.7961e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 3.3233e-07
# Epoch 57/300
# 814/814 [==============================] - 6s 8ms/step - loss: 1.7504e-05 - mse: 4.2900e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5922e-05 - val_mse: 2.7935e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 2.3263e-07
# Epoch 58/300
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7531e-05 - mse: 4.3206e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5917e-05 - val_mse: 2.7902e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 2.3263e-07
# Epoch 59/300
# 810/814 [============================>.] - ETA: 0s - loss: 1.7560e-05 - mse: 4.3517e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.6284130879284928e-07.
# 814/814 [==============================] - 7s 9ms/step - loss: 1.7560e-05 - mse: 4.3514e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5909e-05 - val_mse: 2.7831e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 2.3263e-07
# Epoch 60/300
# 814/814 [==============================] - 6s 7ms/step - loss: 1.7511e-05 - mse: 4.3044e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5910e-05 - val_mse: 2.7907e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.6284e-07
# Epoch 61/300
# 814/814 [==============================] - 6s 7ms/step - loss: 1.7515e-05 - mse: 4.3130e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5905e-05 - val_mse: 2.7840e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.6284e-07
# Epoch 62/300
# 808/814 [============================>.] - ETA: 0s - loss: 1.7504e-05 - mse: 4.3040e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1.1398891217595519e-07.
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7506e-05 - mse: 4.3054e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5904e-05 - val_mse: 2.7867e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.6284e-07
# Epoch 63/300
# 814/814 [==============================] - 6s 8ms/step - loss: 1.7454e-05 - mse: 4.2537e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5905e-05 - val_mse: 2.7904e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.1399e-07
# Epoch 64/300
# 814/814 [==============================] - 5s 6ms/step - loss: 1.7516e-05 - mse: 4.3191e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5901e-05 - val_mse: 2.7881e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.1399e-07
# Epoch 65/300
# 811/814 [============================>.] - ETA: 0s - loss: 1.7497e-05 - mse: 4.3004e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 65: ReduceLROnPlateau reducing learning rate to 7.97922375284088e-08.
# 814/814 [==============================] - 6s 7ms/step - loss: 1.7501e-05 - mse: 4.3051e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5900e-05 - val_mse: 2.7865e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.1399e-07
# Epoch 66/300
# 814/814 [==============================] - 6s 7ms/step - loss: 1.7499e-05 - mse: 4.3054e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5898e-05 - val_mse: 2.7867e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 7.9792e-08
# Epoch 67/300
# 814/814 [==============================] - 6s 8ms/step - loss: 1.7539e-05 - mse: 4.3461e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5894e-05 - val_mse: 2.7816e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 7.9792e-08
# Epoch 68/300
# 805/814 [============================>.] - ETA: 0s - loss: 1.7516e-05 - mse: 4.3236e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 68: ReduceLROnPlateau reducing learning rate to 5.585456577250625e-08.
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7512e-05 - mse: 4.3199e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5896e-05 - val_mse: 2.7878e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 7.9792e-08
# Epoch 69/300
# 814/814 [==============================] - 6s 7ms/step - loss: 1.7556e-05 - mse: 4.3656e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5895e-05 - val_mse: 2.7875e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 5.5855e-08
# Epoch 70/300
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7473e-05 - mse: 4.2823e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5896e-05 - val_mse: 2.7915e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 5.5855e-08
# Epoch 71/300
# 805/814 [============================>.] - ETA: 0s - loss: 1.7537e-05 - mse: 4.3488e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 71: ReduceLROnPlateau reducing learning rate to 3.90981970355142e-08.
# 814/814 [==============================] - 6s 8ms/step - loss: 1.7538e-05 - mse: 4.3496e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5892e-05 - val_mse: 2.7842e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 5.5855e-08
# Epoch 72/300
# 814/814 [==============================] - 6s 7ms/step - loss: 1.7471e-05 - mse: 4.2821e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5894e-05 - val_mse: 2.7880e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 3.9098e-08
# Epoch 73/300
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7515e-05 - mse: 4.3270e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5892e-05 - val_mse: 2.7846e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 3.9098e-08
# Epoch 74/300
# 810/814 [============================>.] - ETA: 0s - loss: 1.7527e-05 - mse: 4.3392e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 74: ReduceLROnPlateau reducing learning rate to 2.7368737676169985e-08.
# 814/814 [==============================] - 6s 8ms/step - loss: 1.7527e-05 - mse: 4.3385e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5890e-05 - val_mse: 2.7837e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 3.9098e-08
# Epoch 75/300
# 814/814 [==============================] - 6s 7ms/step - loss: 1.7438e-05 - mse: 4.2497e-06 - mae: 0.0012 - root_mean_squared_error: 0.0021 - val_loss: 1.5891e-05 - val_mse: 2.7852e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 2.7369e-08
# Epoch 76/300
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7487e-05 - mse: 4.3008e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5889e-05 - val_mse: 2.7825e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 2.7369e-08
# Epoch 77/300
# 810/814 [============================>.] - ETA: 0s - loss: 1.7487e-05 - mse: 4.2988e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 77: ReduceLROnPlateau reducing learning rate to 1.9158116870698905e-08.
# 814/814 [==============================] - 5s 6ms/step - loss: 1.7487e-05 - mse: 4.2985e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5890e-05 - val_mse: 2.7839e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 2.7369e-08
# Epoch 78/300
# 814/814 [==============================] - 6s 7ms/step - loss: 1.7522e-05 - mse: 4.3357e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5890e-05 - val_mse: 2.7841e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.9158e-08
# Epoch 79/300
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7586e-05 - mse: 4.4003e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5889e-05 - val_mse: 2.7827e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.9158e-08
# Epoch 80/300
# 812/814 [============================>.] - ETA: 0s - loss: 1.7458e-05 - mse: 4.2715e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1.3410681809489232e-08.
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7463e-05 - mse: 4.2764e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5889e-05 - val_mse: 2.7820e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.9158e-08
# Epoch 81/300
# 814/814 [==============================] - 6s 8ms/step - loss: 1.7501e-05 - mse: 4.3143e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5889e-05 - val_mse: 2.7831e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.3411e-08
# Epoch 82/300
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7471e-05 - mse: 4.2838e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5889e-05 - val_mse: 2.7834e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.3411e-08
# Epoch 83/300
# 813/814 [============================>.] - ETA: 0s - loss: 1.7503e-05 - mse: 4.3165e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 83: ReduceLROnPlateau reducing learning rate to 9.387477017952506e-09.
# 814/814 [==============================] - 6s 7ms/step - loss: 1.7503e-05 - mse: 4.3159e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5889e-05 - val_mse: 2.7823e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 1.3411e-08
# Epoch 84/300
# 814/814 [==============================] - 6s 7ms/step - loss: 1.7530e-05 - mse: 4.3433e-06 - mae: 0.0012 - root_mean_squared_error: 0.0021 - val_loss: 1.5889e-05 - val_mse: 2.7823e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 9.3875e-09
# Epoch 85/300
# 814/814 [==============================] - 5s 7ms/step - loss: 1.7537e-05 - mse: 4.3495e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5889e-05 - val_mse: 2.7828e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 9.3875e-09
# Epoch 86/300
# 807/814 [============================>.] - ETA: 0s - loss: 1.7483e-05 - mse: 4.2943e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021
# Epoch 86: ReduceLROnPlateau reducing learning rate to 6.5712342234292e-09.
# Restoring model weights from the end of the best epoch: 80.
# 814/814 [==============================] - 6s 8ms/step - loss: 1.7481e-05 - mse: 4.2935e-06 - mae: 0.0013 - root_mean_squared_error: 0.0021 - val_loss: 1.5889e-05 - val_mse: 2.7837e-06 - val_mae: 0.0011 - val_root_mean_squared_error: 0.0017 - lr: 9.3875e-09
# Epoch 86: early stopping

# %%
GAMMA_RTrainHistDf = pd.DataFrame(gm4_TrainHistory.history)
GAMMA_RTrainHistDf.plot(figsize=(12,15), logy=True, logx=True)
plt.grid(True)
plt.gca().set_ylim(0,GAMMA_RTrainHistDf.values.max())
plt.show()
# Out:
# <ipython-input-31-a60ae996d876>:4: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.gca().set_ylim(0,GAMMA_RTrainHistDf.values.max())

# %% [markdown]
# ## Testing

# %%
GAMMA_R.evaluate(gm4_ds_test)
# Out:
# 217/217 [==============================] - 67s 280ms/step - loss: 1.5960e-05 - mse: 2.8141e-06 - mae: 0.0011 - root_mean_squared_error: 0.0017
# [1.596016409166623e-05,
#  2.814080289681442e-06,
#  0.001079175854101777,
#  0.0016775219701230526]

# %%
n_print = 20

for (xs, ys) in gm4_ds_test.take(1):
  preds = GAMMA_R.predict(xs)
  for i in range(n_print):
    # print("Inputs: {}".format(xs[i]))
    print("True: {} | Pred: {}".format(ys[i], preds[i]))
    # print("-"*10)
# Out:
# 16/16 [==============================] - 0s 2ms/step
# True: [0.21600] | Pred: [0.21787]
# True: [0.22800] | Pred: [0.22963]
# True: [0.26400] | Pred: [0.26460]
# True: [0.23400] | Pred: [0.23502]
# True: [0.24000] | Pred: [0.23951]
# True: [0.26400] | Pred: [0.26063]
# True: [0.24600] | Pred: [0.24626]
# True: [0.24600] | Pred: [0.24577]
# True: [0.28200] | Pred: [0.28202]
# True: [0.29400] | Pred: [0.29459]
# True: [0.19800] | Pred: [0.19875]
# True: [0.23400] | Pred: [0.23317]
# True: [0.13800] | Pred: [0.14000]
# True: [0.09000] | Pred: [0.08951]
# True: [0.19800] | Pred: [0.19759]
# True: [0.12000] | Pred: [0.12151]
# True: [0.19200] | Pred: [0.19141]
# True: [0.19200] | Pred: [0.19303]
# True: [0.24600] | Pred: [0.24460]
# True: [0.14400] | Pred: [0.14402]

# %%
scatter_accuracy(ys, preds)

# %%
GAMMA_R.save(gm4_best_save)
GAMMA_R.save_weights(gm4_best_save_weights)
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <__main__.ResnetBlock object at 0x7f0be03fc5b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <__main__.ResnetBlock object at 0x7f0be0400df0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f0be0400f40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f0c6048e400>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f0be0403910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.regularization.dropout.Dropout object at 0x7f0be0403d30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f0be0408640>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f0be0408d00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f0be040c1c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.regularization.dropout.Dropout object at 0x7f0be040c5e0>, because it is not built.
# WARNING:absl:Found untraced functions such as call, call while saving (showing 2 of 2). These functions will not be directly callable after loading.

# %%
GAMMA_RTrainHistDf.to_csv(gm4_save_root/"train_hist.csv")
