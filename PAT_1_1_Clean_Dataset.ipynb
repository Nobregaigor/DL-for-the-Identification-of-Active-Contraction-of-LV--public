# %%
import numpy as np
import pandas as pd
# pd.options.plotting.backend = "plotly" 
from pathlib import Path
import os

# %% [markdown]
# # Read file

# %%
datasetpath = Path("./private/data")
filepath = datasetpath/"geometrics_pat_raw.feather"
raw_df = pd.read_feather(filepath)

# %% [markdown]
# Display df summary

# %%
raw_df
# Out:
#        Unnamed: 0  index  timesteps     volume  longitudinal_distance  \
# 0               0      0      0.000  95993.984              80.715950
# 1               1      1      0.025  94545.586              80.735420
# 2               2      2      0.050  93108.055              80.849976
# 3               3      3      0.075  91753.710              81.016075
# 4               4      4      0.100  90419.945              81.200590
# ...           ...    ...        ...        ...                    ...
# 44186       44186      3      0.075  47937.145              70.484570
# 44187       44187      0      0.000  95993.984              80.715950
# 44188       44188      1      0.025  71262.960              76.904625
# 44189       44189      2      0.050  56420.016              72.960840
# 44190       44190      3      0.075  47746.550              70.274480
#
#        longitudinal_distance_endo  longitudinal_distance_epi  radial_distance  \
# 0                       75.205414                  86.226480        24.911090
# 1                       75.226260                  86.244580        24.791353
# 2                       75.350390                  86.349556        24.657368
# 3                       75.536575                  86.495580        24.521790
# 4                       75.740440                  86.660736        24.383870
# ...                           ...                        ...              ...
# 44186                   65.840100                  75.129040        21.473080
# 44187                   75.205414                  86.226480        24.911090
# 44188                   71.754420                  82.054840        23.245422
# 44189                   68.148820                  77.772865        22.233751
# 44190                   65.511086                  75.037880        21.506367
#
#        radial_distance_endo  radial_distance_epi  ...  \
# 0                 17.919157            31.903027  ...
# 1                 17.767841            31.814867  ...
# 2                 17.603348            31.711388  ...
# 3                 17.439661            31.603920  ...
# 4                 17.273918            31.493822  ...
# ...                     ...                  ...  ...
# 44186             12.479683            30.466476  ...
# 44187             17.919157            31.903027  ...
# 44188             15.480788            31.010057  ...
# 44189             13.746766            30.720736  ...
# 44190             12.511019            30.501715  ...
#
#        angle_rotation_supermid  angle_rotation_base  angle_rotation_superapex  \
# 0                     0.000229             0.000222                  0.000242
# 1                     4.415042             3.589304                  5.002478
# 2                     5.120293             4.582282                  2.586459
# 3                     4.221421             5.026219                  5.182783
# 4                     4.105509             3.574682                  3.808122
# ...                        ...                  ...                       ...
# 44186                 9.089315             5.893949                 25.666544
# 44187                 0.000232             0.000222                  0.000246
# 44188                 4.093487             3.499357                  8.518969
# 44189                 5.728265             4.821286                 15.969993
# 44190                 9.297316             5.882878                 26.100020
#
#        angle_rotation_subapex  angle_rotation_superbase  angle_rotation_apex  \
# 0                    0.000276                  0.000221             0.000256
# 1                    5.264398                  2.680473             4.314641
# 2                    4.091838                  4.611235             4.412965
# 3                    6.056025                  4.788526             4.780913
# 4                    5.125802                  4.408481             6.856593
# ...                       ...                       ...                  ...
# 44186               44.174255                  7.454703            33.235630
# 44187                0.000294                  0.000221             0.000260
# 44188               14.345052                  3.626334            10.593191
# 44189               28.837597                  6.404929            23.102774
# 44190               44.563805                  7.133878            33.572950
#
#        angle_rotation_mid  gamma  endo   epi
# 0                0.000233   0.02  40.0 -40.0
# 1                1.340255   0.02  40.0 -40.0
# 2                2.723759   0.02  40.0 -40.0
# 3                3.121322   0.02  40.0 -40.0
# 4                2.692253   0.02  40.0 -40.0
# ...                   ...    ...   ...   ...
# 44186           15.363367   0.30  80.0 -75.0
# 44187            0.000236   0.30  80.0 -80.0
# 44188            2.938308   0.30  80.0 -80.0
# 44189            9.886219   0.30  80.0 -80.0
# 44190           15.606692   0.30  80.0 -80.0
#
# [44191 rows x 168 columns]

# %%
raw_df.describe()
# Out:
#         Unnamed: 0         index     timesteps         volume  \
# count  44191.00000  44191.000000  44191.000000   44191.000000
# mean   22095.00000     21.309384      0.532735   93356.275559
# std    12756.98721     13.246313      0.331158   35912.696045
# min        0.00000      0.000000      0.000000   38254.926000
# 25%    11047.50000     10.000000      0.250000   60339.217000
# 50%    22095.00000     21.000000      0.525000   91544.040000
# 75%    33142.50000     33.000000      0.825000  124063.475000
# max    44190.00000     44.000000      1.100000  166404.300000
#
#        longitudinal_distance  longitudinal_distance_endo  \
# count           44191.000000                44191.000000
# mean               83.081047                   78.091007
# std                 6.467690                    6.498578
# min                68.511640                   63.818768
# 25%                78.277482                   73.173840
# 50%                82.686260                   77.616000
# 75%                88.744890                   83.814225
# max                98.372505                   93.114860
#
#        longitudinal_distance_epi  radial_distance  radial_distance_endo  \
# count               44191.000000     44191.000000          44191.000000
# mean                   88.071087        24.121689             16.871004
# std                     6.460804         2.342705              3.357035
# min                    72.350980        18.452143              9.653598
# 25%                    83.361543        22.123207             13.960006
# 50%                    87.766320        24.240274             17.154324
# 75%                    93.670325        26.065604             19.731353
# max                   103.630150        28.541166             22.926820
#
#        radial_distance_epi  ...  angle_rotation_supermid  angle_rotation_base  \
# count         44191.000000  ...             44191.000000         44191.000000
# mean             31.372374  ...                 9.076457             5.688548
# std               1.369699  ...                 3.385726             1.726900
# min              27.187462  ...                 0.000228             0.000222
# 25%              30.318745  ...                 6.767383             4.788526
# 50%              31.367378  ...                 9.343103             5.745832
# 75%              32.413632  ...                11.404609             6.621209
# max              34.250916  ...                28.302540            17.867872
#
#        angle_rotation_superapex  angle_rotation_subapex  \
# count              44191.000000            44191.000000
# mean                  14.775763               25.764874
# std                    6.290243               11.042933
# min                    0.000239                0.000267
# 25%                   10.297122               18.784472
# 50%                   15.032620               26.262130
# 75%                   18.929707               32.653190
# max                   38.412598               64.001175
#
#        angle_rotation_superbase  angle_rotation_apex  angle_rotation_mid  \
# count              44191.000000         44191.000000        44191.000000
# mean                   5.982390            18.824535           10.488592
# std                    1.786974             8.688479            4.489403
# min                    0.000221             0.000248            0.000231
# 25%                    5.148010            13.099758            7.726323
# 50%                    5.966032            18.733023           10.640171
# 75%                    6.838466            23.184262           13.348327
# max                   17.828835            55.112083           36.454678
#
#               gamma          endo           epi
# count  44191.000000  44191.000000  44191.000000
# mean       0.128777     59.746442    -61.164377
# std        0.087982     12.782259     12.678249
# min        0.000000     40.000000    -80.000000
# 25%        0.060000     50.000000    -70.000000
# 50%        0.120000     60.000000    -60.000000
# 75%        0.200000     70.000000    -50.000000
# max        0.300000     80.000000    -40.000000
#
# [8 rows x 168 columns]

# %% [markdown]
# # Apply initial modifications

# %% [markdown]
# Copy initial raw df

# %%
df = pd.DataFrame.copy(raw_df)

# %%
df = df.select_dtypes(['number'])
df.head()
# Out:
#    Unnamed: 0  index  timesteps     volume  longitudinal_distance  \
# 0           0      0      0.000  95993.984              80.715950
# 1           1      1      0.025  94545.586              80.735420
# 2           2      2      0.050  93108.055              80.849976
# 3           3      3      0.075  91753.710              81.016075
# 4           4      4      0.100  90419.945              81.200590
#
#    longitudinal_distance_endo  longitudinal_distance_epi  radial_distance  \
# 0                   75.205414                  86.226480        24.911090
# 1                   75.226260                  86.244580        24.791353
# 2                   75.350390                  86.349556        24.657368
# 3                   75.536575                  86.495580        24.521790
# 4                   75.740440                  86.660736        24.383870
#
#    radial_distance_endo  radial_distance_epi  ...  angle_rotation_supermid  \
# 0             17.919157            31.903027  ...                 0.000229
# 1             17.767841            31.814867  ...                 4.415042
# 2             17.603348            31.711388  ...                 5.120293
# 3             17.439661            31.603920  ...                 4.221421
# 4             17.273918            31.493822  ...                 4.105509
#
#    angle_rotation_base  angle_rotation_superapex  angle_rotation_subapex  \
# 0             0.000222                  0.000242                0.000276
# 1             3.589304                  5.002478                5.264398
# 2             4.582282                  2.586459                4.091838
# 3             5.026219                  5.182783                6.056025
# 4             3.574682                  3.808122                5.125802
#
#    angle_rotation_superbase  angle_rotation_apex  angle_rotation_mid  gamma  \
# 0                  0.000221             0.000256            0.000233   0.02
# 1                  2.680473             4.314641            1.340255   0.02
# 2                  4.611235             4.412965            2.723759   0.02
# 3                  4.788526             4.780913            3.121322   0.02
# 4                  4.408481             6.856593            2.692253   0.02
#
#    endo   epi
# 0  40.0 -40.0
# 1  40.0 -40.0
# 2  40.0 -40.0
# 3  40.0 -40.0
# 4  40.0 -40.0
#
# [5 rows x 168 columns]

# %%
from enum import Enum
class DATA(Enum):
    DISP = "displacement"
    DISPLACEMENT = "displacement"
    STRESS = "stress"

    XYZ = "xyz"
    POS = "xyz"
    POSITION = "xyz"

    VOLUME = "volume"
    VOL = "volume"

    VOLUMETRIC_FRACTION = "volumetric_fraction"
    VF = "volumetric_fraction"
    EF = "volumetric_fraction"
    
    
    BASE_REF = "base_ref"
    APEX_REF = "apex_ref"
    
    CENTERS = "centers" # used for spk centers

    LONGITUDINAL_DISTANCE = "longitudinal_distance"
    LONG_DISTS = "longitudinal_distance"

    LONGITUDINAL_SHORTENING = "longitudinal_shortening"
    LS = "longitudinal_shortening"

    # RADIUS = "radius"
    RADIAL_DISTANCE = "radial_distance"
    RADIAL_LENGTH = "radial_length"

    RADIAL_SHORTENING = "radial_shortening"
    RS = "radial_shortening"

    WALL_THICKNESS = "wall_thickness"
    THICKNESS = "wall_thickness"

    WALL_THICKENING = "wall_thickening"
    THICKENING = "wall_thickening"
    WT = "wall_thickening"
    
    LONG_LENGTH = "longitudinal_length"
    LONGITUDINAL_LENGTH = "longitudinal_length"
    GLOBAL_LONGITUDINAL_LENGTH = "global_longitudinal_length"
    GLOBAL_LONG_LENGTH = "global_longitudinal_length"

    LONGITUDINAL_STRAIN = "longitudinal_strain"
    LONG_STRAIN = "longitudinal_strain"
    SL = "longitudinal_strain"

    CIRC_LENGTH = "circumferential_length"
    CIRCUMFERENTIAL_LENGTH = "circumferential_length"
    GLOBAL_CIRCUMFERENTIAL_LENGTH = "global_circumferential_length"
    GLOBAL_CIRC_LENGTH = "global_circumferential_length"

    CIRCUMFERENTIAL_STRAIN = "circumferential_strain"
    CIRC_STRAIN = "circumferential_strain"
    SC = "circumferential_strain"
    
    SPK_VECS = "spckle_vectors"

    ROTATION = "angle_rotation"
    RO = "angle_rotation"

    TWIST = "twist"
    TW = "twist"

    TORSION = "torsion"
    TO = "torsion"

# %%
df = df[[
         "timesteps", # will need for some computations in this notebook
         "gamma",
         "endo",
         "epi",
         DATA.VOLUME.value, 
         DATA.LONGITUDINAL_DISTANCE.value + "_epi",
         DATA.LONGITUDINAL_DISTANCE.value + "_endo",
         DATA.LONGITUDINAL_DISTANCE.value,
         DATA.RADIAL_DISTANCE.value + "_epi",
         DATA.RADIAL_DISTANCE.value + "_endo",
         DATA.RADIAL_DISTANCE.value,
         DATA.THICKNESS.value,
         DATA.GLOBAL_LONGITUDINAL_LENGTH.value + "_epi",
         DATA.GLOBAL_LONGITUDINAL_LENGTH.value + "_endo",
         DATA.GLOBAL_LONGITUDINAL_LENGTH.value,
         DATA.GLOBAL_CIRCUMFERENTIAL_LENGTH.value + "_epi",
         DATA.GLOBAL_CIRCUMFERENTIAL_LENGTH.value + "_endo",
         DATA.GLOBAL_CIRCUMFERENTIAL_LENGTH.value,

         ]]
df.head()
# Out:
#    timesteps  gamma  endo   epi     volume  longitudinal_distance_epi  \
# 0      0.000   0.02  40.0 -40.0  95993.984                  86.226480
# 1      0.025   0.02  40.0 -40.0  94545.586                  86.244580
# 2      0.050   0.02  40.0 -40.0  93108.055                  86.349556
# 3      0.075   0.02  40.0 -40.0  91753.710                  86.495580
# 4      0.100   0.02  40.0 -40.0  90419.945                  86.660736
#
#    longitudinal_distance_endo  longitudinal_distance  radial_distance_epi  \
# 0                   75.205414              80.715950            31.903027
# 1                   75.226260              80.735420            31.814867
# 2                   75.350390              80.849976            31.711388
# 3                   75.536575              81.016075            31.603920
# 4                   75.740440              81.200590            31.493822
#
#    radial_distance_endo  radial_distance  wall_thickness  \
# 0             17.919157        24.911090       13.983870
# 1             17.767841        24.791353       14.047026
# 2             17.603348        24.657368       14.108041
# 3             17.439661        24.521790       14.164259
# 4             17.273918        24.383870       14.219904
#
#    global_longitudinal_length_epi  global_longitudinal_length_endo  \
# 0                       214.93320                        174.17569
# 1                       214.74474                        173.99507
# 2                       214.67905                        173.98230
# 3                       214.68806                        174.05412
# 4                       214.72853                        174.16040
#
#    global_longitudinal_length  global_circumferential_length_epi  \
# 0                   194.55444                          203.40485
# 1                   194.36990                          202.83585
# 2                   194.33067                          202.16810
# 3                   194.37110                          201.47760
# 4                   194.44447                          200.77391
#
#    global_circumferential_length_endo  global_circumferential_length
# 0                          120.390305                      161.89757
# 1                          119.425740                      161.13080
# 2                          118.382380                      160.27524
# 3                          117.343770                      159.41069
# 4                          116.296250                      158.53508

# %% [markdown]
# normalie volume

# %%
INITIAL_VOL = df[df["timesteps"] == 0][DATA.VOLUME.value].iloc[0]
df[DATA.VOLUME.value] /= INITIAL_VOL
df.head()
# Out:
#    timesteps  gamma  endo   epi    volume  longitudinal_distance_epi  \
# 0      0.000   0.02  40.0 -40.0  1.000000                  86.226480
# 1      0.025   0.02  40.0 -40.0  0.984912                  86.244580
# 2      0.050   0.02  40.0 -40.0  0.969936                  86.349556
# 3      0.075   0.02  40.0 -40.0  0.955828                  86.495580
# 4      0.100   0.02  40.0 -40.0  0.941933                  86.660736
#
#    longitudinal_distance_endo  longitudinal_distance  radial_distance_epi  \
# 0                   75.205414              80.715950            31.903027
# 1                   75.226260              80.735420            31.814867
# 2                   75.350390              80.849976            31.711388
# 3                   75.536575              81.016075            31.603920
# 4                   75.740440              81.200590            31.493822
#
#    radial_distance_endo  radial_distance  wall_thickness  \
# 0             17.919157        24.911090       13.983870
# 1             17.767841        24.791353       14.047026
# 2             17.603348        24.657368       14.108041
# 3             17.439661        24.521790       14.164259
# 4             17.273918        24.383870       14.219904
#
#    global_longitudinal_length_epi  global_longitudinal_length_endo  \
# 0                       214.93320                        174.17569
# 1                       214.74474                        173.99507
# 2                       214.67905                        173.98230
# 3                       214.68806                        174.05412
# 4                       214.72853                        174.16040
#
#    global_longitudinal_length  global_circumferential_length_epi  \
# 0                   194.55444                          203.40485
# 1                   194.36990                          202.83585
# 2                   194.33067                          202.16810
# 3                   194.37110                          201.47760
# 4                   194.44447                          200.77391
#
#    global_circumferential_length_endo  global_circumferential_length
# 0                          120.390305                      161.89757
# 1                          119.425740                      161.13080
# 2                          118.382380                      160.27524
# 3                          117.343770                      159.41069
# 4                          116.296250                      158.53508

# %% [markdown]
# Remove gamma-ramp timesteps

# %%
df = pd.DataFrame.copy(df[df.timesteps >= 0.1])
df.timesteps -= 0.1
df.head()
# Out:
#    timesteps  gamma  endo   epi    volume  longitudinal_distance_epi  \
# 4      0.000   0.02  40.0 -40.0  0.941933                  86.660736
# 5      0.025   0.02  40.0 -40.0  1.047654                  89.510430
# 6      0.050   0.02  40.0 -40.0  1.133637                  91.811560
# 7      0.075   0.02  40.0 -40.0  1.195653                  93.058685
# 8      0.100   0.02  40.0 -40.0  1.244868                  93.993460
#
#    longitudinal_distance_endo  longitudinal_distance  radial_distance_epi  \
# 4                   75.740440               81.20059            31.493822
# 5                   78.888790               84.19961            31.744463
# 6                   81.642365               86.72696            31.846136
# 7                   83.032200               88.04545            31.999588
# 8                   84.065796               89.02963            32.124363
#
#    radial_distance_endo  radial_distance  wall_thickness  \
# 4             17.273918        24.383870       14.219904
# 5             18.081738        24.913100       13.662725
# 6             18.616634        25.231386       13.229503
# 7             19.026691        25.513140       12.972896
# 8             19.343134        25.733747       12.781230
#
#    global_longitudinal_length_epi  global_longitudinal_length_endo  \
# 4                       214.72853                        174.16040
# 5                       220.09288                        180.72203
# 6                       224.43607                        186.39972
# 7                       227.04747                        189.54195
# 8                       229.03877                        191.88106
#
#    global_longitudinal_length  global_circumferential_length_epi  \
# 4                   194.44447                          200.77391
# 5                   200.40746                          202.26007
# 6                   205.41790                          202.93109
# 7                   208.29471                          203.91121
# 8                   210.45992                          204.70692
#
#    global_circumferential_length_endo  global_circumferential_length
# 4                          116.296250                      158.53508
# 5                          121.011116                      161.63559
# 6                          124.462776                      163.69693
# 7                          127.141900                      165.52655
# 8                          129.213870                      166.96039

# %% [markdown]
# remove unfinished simulations

# %%
dfgrouped = df.groupby(["endo", "epi", "gamma"])
print("before:", df["timesteps"].count())
df_filtered = []
for k, group in dfgrouped:
  if group["timesteps"].count() <= 12:
    continue
  df_filtered.append(group)
df = pd.concat(df_filtered)
print("after:", df["timesteps"].count())
# Out:
# before: 39293
# after: 38897

# %% [markdown]
# add pressure

# %%
# df = pd.DataFrame.copy(raw_df)
IDEAL = str(datasetpath).lower().find("ideal") >= 0
print("using ideal:", IDEAL)

if IDEAL:
  max_pressure_computed = 20.0 # 20 for ideal, 24 for LV
  df["pressure"] = max_pressure_computed*df["timesteps"]
else:
  max_pressure_computed = 25.0 #16 for ideal, 24 for LV
  df["pressure"] = max_pressure_computed*df["timesteps"]
# Out:
# using ideal: False

# %%
df["pressure"].describe()
# Out:
# count    38897.000000
# mean        12.479336
# std          7.394453
# min          0.000000
# 25%          6.250000
# 50%         12.500000
# 75%         18.750000
# max         25.000000
# Name: pressure, dtype: float64

# %% [markdown]
# remove timesteps (no longer necessary)

# %%
df.drop("timesteps", axis=1, inplace=True)

# %% [markdown]
# remove outliers

# %%
dfgrouped = df.groupby(["endo", "epi", "gamma"])
print("before:", df["pressure"].count())
df_filtered = []
for k, group in dfgrouped:
  Q1 = group.quantile(0.03)
  Q3 = group.quantile(0.97)
  IQR = Q3 - Q1
  group = pd.DataFrame.copy(group[~((group < (Q1 - 3 * IQR)) |(group > (Q3 + 3 * IQR))).any(axis=1)])
  df_filtered.append(group)
df = pd.concat(df_filtered)
print("after:", df["pressure"].count())
# Out:
# before: 38897
# after: 38897

# %%
from scipy import stats
print("before:", df["pressure"].count())
df = pd.DataFrame.copy(df[(np.abs(stats.zscore(df)) < 3).all(axis=1)])
print("after:", df["pressure"].count())
# Out:
# before: 38897
# after: 38897

# %%
Q1 = df.quantile(0.01)
Q3 = df.quantile(0.99)
IQR = Q3 - Q1
print("before:", df["pressure"].count())
df = pd.DataFrame.copy(df[~((df < (Q1 - 3 * IQR)) |(df > (Q3 + 3 * IQR))).any(axis=1)])
print("after:", df["pressure"].count())
# Out:
# before: 38897
# after: 38897

# %% [markdown]
# # Apply Interpolation in pressure-gamma

# %%
dfgrouped = df.groupby(["endo", "epi"])

# %%
max_pressure = np.round(df["pressure"].max())
max_pressure = min([25, max_pressure])
max_pressure
# Out:
# 25

# %%
df["pressure"].max()
# Out:
# 25.0

# %%
from scipy.interpolate import griddata, interp2d, RectBivariateSpline
from scipy.ndimage import gaussian_filter

nsteps = 50

xx = np.linspace(0, 20,nsteps+1)    # pressure -> 20
yy =  np.linspace(0, 0.30, nsteps+1) # gamma
X, Y = np.meshgrid(xx,yy)

new_grouped = dict()

for k, group in dfgrouped:
  new_grouped[k] = dict()
  new_grouped[k]["gamma"] = Y.ravel()
  new_grouped[k]["pressure"] = X.ravel()

  x = group["pressure"]
  y = group["gamma"]

  for col in group.columns:
    if col in ["gamma", "pressure", "endo", "epi"]:
      continue 
    z = group[col]
    first_interp = griddata((x,y), z, (X, Y), method="linear", rescale=True).ravel()
    nearest_interp = griddata((x,y), z, (X, Y), method="nearest", rescale=True).ravel()
    new_grouped[k][col] = np.where(np.isnan(first_interp), nearest_interp, first_interp)

# %%
new_df_groups = []
for k, group in new_grouped.items():
  _gdf = pd.DataFrame(group)
  _gdf["endo"] = k[0]
  _gdf["epi"] = k[1]
  new_df_groups.append(_gdf)
df2 = pd.concat(new_df_groups)

# %%
df = pd.DataFrame.copy(df2)

# %%
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#                gamma       pressure         volume  longitudinal_distance_epi  \
# count  210681.000000  210681.000000  210681.000000              210681.000000
# mean        0.150000      10.000000       0.887015                  87.210732
# std         0.088318       5.887855       0.358111                   6.626441
# min         0.000000       0.000000       0.400717                  72.854540
# 25%         0.072000       4.800000       0.544515                  81.924440
# 50%         0.150000      10.000000       0.831888                  87.412503
# 75%         0.228000      15.200000       1.179203                  92.789712
# max         0.300000      20.000000       1.698764                 102.986896
#
#        longitudinal_distance_endo  longitudinal_distance  radial_distance_epi  \
# count               210681.000000          210681.000000        210681.000000
# mean                    77.320808              82.265770            31.014558
# std                      6.556922               6.577404             1.356140
# min                     63.821816              68.511640            27.198589
# 25%                     71.769242              76.831132            29.998074
# 50%                     77.403059              82.403444            30.862974
# 75%                     82.891272              87.843551            32.062701
# max                     92.519202              97.748764            34.162830
#
#        radial_distance_endo  radial_distance  wall_thickness  \
# count         210681.000000    210681.000000   210681.000000
# mean              16.012062        23.513310       15.002497
# std                3.339686         2.321168        2.105696
# min                9.653598        18.452143       11.288178
# 25%               12.869878        21.426119       13.120564
# 50%               15.884759        23.354636       14.920831
# 75%               18.887670        25.459648       16.963205
# max               22.748425        28.405220       18.999577
#
#        global_longitudinal_length_epi  global_longitudinal_length_endo  \
# count                   210681.000000                    210681.000000
# mean                       218.987958                       176.400739
# std                         11.190098                        15.590917
# min                        195.881590                       147.678300
# 25%                        209.805820                       162.404658
# 50%                        218.690687                       175.973796
# 75%                        228.474052                       190.153761
# max                        243.498766                       208.662450
#
#        global_longitudinal_length  global_circumferential_length_epi  \
# count               210681.000000                      210681.000000
# mean                   197.694348                         197.458590
# std                     13.310725                           8.637911
# min                    172.620100                         173.444603
# 25%                    186.178619                         190.967710
# 50%                    197.231455                         196.492870
# 75%                    209.215529                         204.114374
# max                    226.080599                         217.570740
#
#        global_circumferential_length_endo  global_circumferential_length  \
# count                       210681.000000                  210681.000000
# mean                           108.999168                     153.228879
# std                             20.378113                      14.330878
# min                             74.453590                     124.227115
# 25%                             89.086090                     140.062633
# 50%                            108.021008                     152.125710
# 75%                            126.721744                     165.320067
# max                            150.345920                     183.658600
#
#                 endo            epi
# count  210681.000000  210681.000000
# mean       60.000000     -60.000000
# std        12.909975      12.909975
# min        40.000000     -80.000000
# 25%        50.000000     -70.000000
# 50%        60.000000     -60.000000
# 75%        70.000000     -50.000000
# max        80.000000     -40.000000

# %% [markdown]
# # Apply interpolation in endo-epi

# %%
dfgrouped = df.groupby(["gamma", "pressure"])

# %%
from scipy.interpolate import griddata, interp2d, RectBivariateSpline

nsteps = 20

xx = np.linspace(40, 80, nsteps+1) # endo
yy =  np.linspace(-80, -40,nsteps+1)  # epi
X, Y = np.meshgrid(xx,yy)

new_grouped = dict()

for k, group in dfgrouped:
  new_grouped[k] = dict()
  new_grouped[k]["endo"] = X.ravel()
  new_grouped[k]["epi"] = Y.ravel()

  x = group["endo"]
  y = group["epi"]

  for col in group.columns: 
    if col in ["gamma", "pressure", "endo", "epi"]:
      continue 
    z = group[col]
    first_interp = griddata((x,y), z, (X, Y), method="linear", rescale=True).ravel()
    nearest_interp = griddata((x,y), z, (X, Y), method="nearest", rescale=True).ravel()
    new_grouped[k][col] = np.where(np.isnan(first_interp), nearest_interp, first_interp)

# %%
new_df_groups = []
for k, group in new_grouped.items():
  _gdf = pd.DataFrame(group)
  _gdf["gamma"] = k[0]
  _gdf["pressure"] = k[1]
  new_df_groups.append(_gdf)
df2 = pd.concat(new_df_groups)

# %%
df = pd.DataFrame.copy(df2)

# %%
df = df.dropna()

# %%
df.describe()
# Out:
#                endo           epi        volume  longitudinal_distance_epi  \
# count  1.147041e+06  1.147041e+06  1.147041e+06               1.147041e+06
# mean   6.000000e+01 -6.000000e+01  8.863438e-01               8.719466e+01
# std    1.211061e+01  1.211061e+01  3.571998e-01               6.454316e+00
# min    4.000000e+01 -8.000000e+01  4.007173e-01               7.285454e+01
# 25%    5.000000e+01 -7.000000e+01  5.476004e-01               8.200233e+01
# 50%    6.000000e+01 -6.000000e+01  8.265879e-01               8.736802e+01
# 75%    7.000000e+01 -5.000000e+01  1.178540e+00               9.264891e+01
# max    8.000000e+01 -4.000000e+01  1.698764e+00               1.029869e+02
#
#        longitudinal_distance_endo  longitudinal_distance  radial_distance_epi  \
# count                1.147041e+06           1.147041e+06         1.147041e+06
# mean                 7.731678e+01           8.225572e+01         3.101698e+01
# std                  6.398090e+00           6.413306e+00         1.341976e+00
# min                  6.382182e+01           6.851164e+01         2.719859e+01
# 25%                  7.191890e+01           7.694156e+01         3.000284e+01
# 50%                  7.739574e+01           8.237083e+01         3.084572e+01
# 75%                  8.273627e+01           8.768933e+01         3.205957e+01
# max                  9.251920e+01           9.774876e+01         3.416283e+01
#
#        radial_distance_endo  radial_distance  wall_thickness  \
# count          1.147041e+06     1.147041e+06    1.147041e+06
# mean           1.600579e+01     2.351138e+01    1.501119e+01
# std            3.330333e+00     2.312454e+00    2.096248e+00
# min            9.653598e+00     1.845214e+01    1.128818e+01
# 25%            1.288693e+01     2.143254e+01    1.312798e+01
# 50%            1.581771e+01     2.330915e+01    1.496474e+01
# 75%            1.888373e+01     2.545867e+01    1.696464e+01
# max            2.274843e+01     2.840522e+01    1.899958e+01
#
#        global_longitudinal_length_epi  global_longitudinal_length_endo  \
# count                    1.147041e+06                     1.147041e+06
# mean                     2.189271e+02                     1.763726e+02
# std                      1.094555e+01                     1.535735e+01
# min                      1.958864e+02                     1.476783e+02
# 25%                      2.099349e+02                     1.626369e+02
# 50%                      2.185531e+02                     1.758855e+02
# 75%                      2.281423e+02                     1.898346e+02
# max                      2.434988e+02                     2.086624e+02
#
#        global_longitudinal_length  global_circumferential_length_epi  \
# count                1.147041e+06                       1.147041e+06
# mean                 1.976499e+02                       1.974691e+02
# std                  1.308108e+01                       8.549576e+00
# min                  1.726201e+02                       1.734446e+02
# 25%                  1.862738e+02                       1.909941e+02
# 50%                  1.971712e+02                       1.963685e+02
# 75%                  2.088977e+02                       2.040907e+02
# max                  2.260806e+02                       2.175707e+02
#
#        global_circumferential_length_endo  global_circumferential_length  \
# count                        1.147041e+06                   1.147041e+06
# mean                         1.089607e+02                   1.532149e+02
# std                          2.032863e+01                   1.428199e+01
# min                          7.445359e+01                   1.242271e+02
# 25%                          8.918871e+01                   1.400947e+02
# 50%                          1.076372e+02                   1.518347e+02
# 75%                          1.267090e+02                   1.653162e+02
# max                          1.503459e+02                   1.836586e+02
#
#               gamma      pressure
# count  1.147041e+06  1.147041e+06
# mean   1.500000e-01  1.000000e+01
# std    8.831765e-02  5.887843e+00
# min    0.000000e+00  0.000000e+00
# 25%    7.200000e-02  4.800000e+00
# 50%    1.500000e-01  1.000000e+01
# 75%    2.280000e-01  1.520000e+01
# max    3.000000e-01  2.000000e+01

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Bins

# %%
n_bins = 50

bins_keys = []
for v in df.columns:
  k = v+"-b"
  df[k] = (pd.qcut(df[v], q=n_bins, labels=False, duplicates='drop')).astype(int) +1
  bins_keys.append(k)

# %% [markdown]
# normalize pressure

# %%
PRESSURE_NORM = 16.0
df["pressure"] /= PRESSURE_NORM

# %%
df.describe()
# Out:
#                endo           epi        volume  longitudinal_distance_epi  \
# count  1.147041e+06  1.147041e+06  1.147041e+06               1.147041e+06
# mean   6.000000e+01 -6.000000e+01  8.863438e-01               8.719466e+01
# std    1.211061e+01  1.211061e+01  3.571998e-01               6.454316e+00
# min    4.000000e+01 -8.000000e+01  4.007173e-01               7.285454e+01
# 25%    5.000000e+01 -7.000000e+01  5.476004e-01               8.200233e+01
# 50%    6.000000e+01 -6.000000e+01  8.265879e-01               8.736802e+01
# 75%    7.000000e+01 -5.000000e+01  1.178540e+00               9.264891e+01
# max    8.000000e+01 -4.000000e+01  1.698764e+00               1.029869e+02
#
#        longitudinal_distance_endo  longitudinal_distance  radial_distance_epi  \
# count                1.147041e+06           1.147041e+06         1.147041e+06
# mean                 7.731678e+01           8.225572e+01         3.101698e+01
# std                  6.398090e+00           6.413306e+00         1.341976e+00
# min                  6.382182e+01           6.851164e+01         2.719859e+01
# 25%                  7.191890e+01           7.694156e+01         3.000284e+01
# 50%                  7.739574e+01           8.237083e+01         3.084572e+01
# 75%                  8.273627e+01           8.768933e+01         3.205957e+01
# max                  9.251920e+01           9.774876e+01         3.416283e+01
#
#        radial_distance_endo  radial_distance  wall_thickness  ...  \
# count          1.147041e+06     1.147041e+06    1.147041e+06  ...
# mean           1.600579e+01     2.351138e+01    1.501119e+01  ...
# std            3.330333e+00     2.312454e+00    2.096248e+00  ...
# min            9.653598e+00     1.845214e+01    1.128818e+01  ...
# 25%            1.288693e+01     2.143254e+01    1.312798e+01  ...
# 50%            1.581771e+01     2.330915e+01    1.496474e+01  ...
# 75%            1.888373e+01     2.545867e+01    1.696464e+01  ...
# max            2.274843e+01     2.840522e+01    1.899958e+01  ...
#
#        radial_distance-b  wall_thickness-b  global_longitudinal_length_epi-b  \
# count       1.147041e+06      1.147041e+06                      1.147041e+06
# mean        2.549999e+01      2.549999e+01                      2.549998e+01
# std         1.443089e+01      1.443088e+01                      1.443090e+01
# min         1.000000e+00      1.000000e+00                      1.000000e+00
# 25%         1.300000e+01      1.300000e+01                      1.300000e+01
# 50%         2.500000e+01      2.500000e+01                      2.500000e+01
# 75%         3.800000e+01      3.800000e+01                      3.800000e+01
# max         5.000000e+01      5.000000e+01                      5.000000e+01
#
#        global_longitudinal_length_endo-b  global_longitudinal_length-b  \
# count                       1.147041e+06                  1.147041e+06
# mean                        2.549999e+01                  2.549997e+01
# std                         1.443089e+01                  1.443091e+01
# min                         1.000000e+00                  1.000000e+00
# 25%                         1.300000e+01                  1.300000e+01
# 50%                         2.500000e+01                  2.500000e+01
# 75%                         3.800000e+01                  3.800000e+01
# max                         5.000000e+01                  5.000000e+01
#
#        global_circumferential_length_epi-b  \
# count                         1.147041e+06
# mean                          2.549998e+01
# std                           1.443090e+01
# min                           1.000000e+00
# 25%                           1.300000e+01
# 50%                           2.500000e+01
# 75%                           3.800000e+01
# max                           5.000000e+01
#
#        global_circumferential_length_endo-b  global_circumferential_length-b  \
# count                          1.147041e+06                     1.147041e+06
# mean                           2.549999e+01                     2.549997e+01
# std                            1.443090e+01                     1.443092e+01
# min                            1.000000e+00                     1.000000e+00
# 25%                            1.300000e+01                     1.300000e+01
# 50%                            2.500000e+01                     2.500000e+01
# 75%                            3.800000e+01                     3.800000e+01
# max                            5.000000e+01                     5.000000e+01
#
#             gamma-b    pressure-b
# count  1.147041e+06  1.147041e+06
# mean   2.501961e+01  2.501961e+01
# std    1.468692e+01  1.468692e+01
# min    1.000000e+00  1.000000e+00
# 25%    1.200000e+01  1.200000e+01
# 50%    2.500000e+01  2.500000e+01
# 75%    3.800000e+01  3.800000e+01
# max    5.000000e+01  5.000000e+01
#
# [8 rows x 36 columns]

# %% [markdown]
# # Final Clean up

# %% [markdown]
# select only contraction values to eliminate multiple-solution

# %%
df = df[df['volume'] <= 1.0]

# %% [markdown]
# # Save important information in a json file

# %% [markdown]
# ## Suggested Scale

# %%
scales = dict()

for col in df.columns:
  
  scaled = False
  
  if col.find(DATA.VOLUME.value)>=0: # we already normalized volume
    scales[col] = 1.0 
  
  elif col.find("gamma")>=0:
    scales[col] = 1.0
  
  elif col.find("epi")>=0:
    scales[col] = 100.0
  
  elif col.find("endo")>=0:
    scales[col] = 100.0
  
  elif col.find("pressure")>=0:
    scales[col] = 1.0
  
  elif col.endswith("-b"):
    scales[col] = 1.0
  
  else:
    scales[col] = 100.0

# %% [markdown]
# ## json

# %%
import json

# save columns as 'headers' with indices of their col
headers = {col: i for i, col in enumerate(df.columns)}

# save min and max value
val_ranges = dict()
for col in df:
  val_ranges[col] = [float(df[col].min()), float(df[col].max())] 

norms = {
    "pressure": PRESSURE_NORM,
    "volume": INITIAL_VOL
}

to_save = dict(headers=headers, 
               ranges=val_ranges, 
               scales=scales, 
               n_classes=n_bins,
               norms=norms
               )

with open(datasetpath/"header.json", "w") as jsonfile:
  jsonfile.write(json.dumps(to_save))

# %% [markdown]
# # Save new df

# %%
df.reset_index().to_feather(datasetpath/"geometrics_pat_clean.feather")
