# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import os
import pathlib
import matplotlib.pyplot as plt
import matplotlib
from tensorflow.keras import layers

# %% [markdown]
# ## formatting

# %%
float_formatter = "{:.5f}".format
np.set_printoptions(formatter={'float_kind':float_formatter})

plt.style.use('default')
# %matplotlib inline

matplotlib.rcParams.update({'font.size': 10})

# %% [markdown]
# ## Paths and directories

# %%
ROOT_DIR = pathlib.Path("./")
DATA_DIR = ROOT_DIR/"geometrics_pat_clean"

csv_header_filepath = DATA_DIR/"header.json"

train_dir = DATA_DIR/"train"
valid_dir = DATA_DIR/"valid"
test_dir = DATA_DIR/"test"

model_save_root = ROOT_DIR/"models"

# %%
csv_header_filepath
# Out:
# PosixPath('/content/drive/MyDrive/Research/PAPER_1_CODE/geometrics_pat_clean/header.json')

# %%
import json
with open(csv_header_filepath, "r") as jsonfile:
  jsondata = json.load(jsonfile)
header = jsondata["headers"]

# %% [markdown]
# # Utils

# %% [markdown]
# ## Modules

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense

class ResnetBlock(tf.keras.Model):
  def __init__(self, units, dropout_rate=0.001, **kwargs):
    super(ResnetBlock, self).__init__(**kwargs)

    self.units=units
    self.dropout_rate=dropout_rate
    self.dense1 = Dense(units)
    self.dense2 = Dense(units)
    self.dense3 = Dense(units)

    self.dropout = Dropout(dropout_rate)
  
  @tf.function()
  def call(self, input_tensor, training=False):
    x = self.dense1(input_tensor, training=training)
    x = self.dropout(x)
    x = self.dense2(x, training=training)
    x = self.dropout(x)
    x = self.dense3(x, training=training)
    x = self.dropout(x)

    x += input_tensor
    return tf.nn.relu(x)
  
  def get_config(self):
      config = super(ResnetBlock, self).get_config()
      config.update({"units": self.units, "dropout_rate": self.dropout_rate})
      return config

# %%
import tensorflow as tf

class NormalizedBaseClass(tf.keras.losses.Loss):
  def __init__(self, lb=[], up=[], indices=[], epsilon=1e-12, dtype=tf.float32, **kwargs):
    super().__init__(**kwargs)

    self.indices = indices
    self.use_indices = True if len(indices) > 0 else False

    self.epsilon = epsilon
    self.dtype = dtype

    self.lowBound = self.setBounds(lb)
    self.uppBound = self.setBounds(up)
    self.epsilon_tensor = self.setEpsilonTensor(epsilon)
    
    self._dividion_denomiator = tf.maximum(tf.subtract(self.uppBound, self.lowBound, name="denom_sub"), self.epsilon_tensor)    
  
  def setBounds(self, bd):
    return tf.constant(self.gather(bd), dtype=self.dtype)
  
  def setEpsilonTensor(self,epsilon):
    return tf.constant(self.epsilon, dtype=self.dtype, shape=self.lowBound.shape)

  def gather(self, tensor, axis=-1):
    if not self.use_indices:
      return tensor
    gathered = tf.gather(tensor, self.indices, axis=axis)
    if gathered.dtype != self.dtype:
      gathered = tf.cast(gathered, self.dtype)
    return gathered

  def normalize(self, X, gather_x=True):
    if gather_x:
      X = self.gather(X)
    S = tf.subtract(X, self.lowBound, name="norm_sub")
    return tf.divide(S, self._dividion_denomiator, name="norm_div")
  
  def convert_inputs(self, y_true, y_pred, set_dtype=True):
    y_pred = tf.convert_to_tensor(y_pred)    
    y_true = tf.cast(y_true, y_pred.dtype)
    if set_dtype:
      self.setDtype(y_pred.dtype)
    return y_true, y_pred

  def setDtype(self, dtype):
    self.dtype = dtype

  def get_config(self):
    base_config = super().get_config()
    return {**base_config, "lb":self.lb, "up": self.up, "epsilon": self.epsilon}
  
class NormalizedMeanAbsoluteError(NormalizedBaseClass):
  def __init__(self, lb=[], up=[], indices=[], **kwargs):
    super().__init__(**kwargs)
  
  def call(self, y_true, y_pred):
    y_true, y_pred = self.convert_inputs(y_true, y_pred)
    y_true_norm, y_pred_norm = self.normalize(y_true), self.normalize(y_pred, False)
    return tf.math.reduce_mean(tf.abs(y_pred_norm - y_true_norm), axis=-1)
  def get_config(self):
    base_config = super().get_config()
    return {**base_config, "lb":self.lb, "up": self.up, "epsilon": self.epsilon}

class NormalizedMeanSquaredError(NormalizedBaseClass):
  def __init__(self, **kwargs):
    super().__init__(**kwargs)
  
  def call(self, y_true, y_pred):
    y_true, y_pred = self.convert_inputs(y_true, y_pred)
    y_true_norm, y_pred_norm = self.normalize(y_true), self.normalize(y_pred, False)
    return tf.math.reduce_mean(tf.math.square(y_pred_norm - y_true_norm), axis=-1)
  def get_config(self):
    base_config = super().get_config()
    return {**base_config, "lb":self.lb, "up": self.up, "epsilon": self.epsilon}

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense

def build_norm_layer(batch_size, header, labels, feats, name="norm",int_labels=False):
  from tensorflow.keras.layers.experimental import preprocessing
  ds_norm  = csv_ds_reader(train_dir, header, labels, feats, int_labels=int_labels, batch_size=batch_size)
  norm_layer = preprocessing.Normalization(name=name)
  for (xs, _) in ds_norm.take(1):
    norm_layer.adapt(xs)
  return norm_layer

class GAMMA_Regressor_Model(tf.keras.Model):
  def __init__(self, n_units, n_blocks, norm_layer, n_output_labels, **kwargs):
    super(GAMMA_Regressor_Model, self).__init__(**kwargs)

    self.n_units = n_units
    self.n_blocks = n_blocks
    self.norm = norm_layer

    self.d1 = Dense(self.n_units, activation="relu")
    self.l1 = [ResnetBlock(self.n_units, dropout_rate=0.001) for _ in range(n_blocks)]
    self.l2 = [ResnetBlock(self.n_units*2, dropout_rate=0.001) for _ in range(n_blocks)]
    self.l3 = [ResnetBlock(self.n_units*4, dropout_rate=0.001) for _ in range(n_blocks)]

    self.d2 = Dense(self.n_units*2, activation="relu")
    self.d3 = Dense(self.n_units*4, activation="relu")

    self.tail = [
      layers.ActivityRegularization(0.0001, 0.0001),
      Dense(n_output_labels, name="gr_body_out"),
    ]

  def call(self, input_tensor, training=False):
    x_norm = self.norm(input_tensor)
    # x = tf.concat([x_norm, x_bins], axis=1)
    x = self.d1(x_norm)
    for layer in self.l1:
      x = layer(x)
    x = self.d2(x)
    x = self.d3(x)
    for layer in self.tail:
      x = layer(x)
    return x

  def get_config(self):
      # config = super(CM4_Model, self).get_config()
      return {"n_units": self.n_units, "n_blocks": self.n_blocks}

# %% [markdown]
# ## utils

# %%
import json
import pandas as pd
import numpy as np
import tensorflow as tf

def get_indexes(header, of_keys):
  return [header[key]+1 for key in of_keys]

def csv_ds_reader(filepaths, 
                  header,
                  label_keys,
                  feature_keys,
                  int_labels=False,
                  reshape_to=None,
                  batch_size=32,
    repeat=1, n_readers=5, 
    shuffle_buffer_size=10000, 
    cache=True, 
    n_read_threads=None, 
    n_parse_threads=5):
  
  label_indexes = get_indexes(header, label_keys)
  feature_indexes = get_indexes(header, feature_keys)
  
  def get_features_labels(line):
    """
      Re-structures DS to read csv field and return 'features, labels'
    """
    defs = [0.] * (len(header) + 1) #n_labels
    fields = tf.io.decode_csv(line, record_defaults=defs)
 
    # cm-lookup -> CM1 -> (CMs), (FB, PV)
    _labels  = tf.stack([fields[i] for i in label_indexes])
    features = tf.stack([fields[i] for i in feature_indexes])
   
    try:
      tf.debugging.check_numerics(_labels, message='Checking _labels')
    except Exception as e:
      assert "Checking labels: Tensor had NaN values" in e.message
    
    try:
      tf.debugging.check_numerics(features, message='Checking features')
    except Exception as e:
      assert "Checking features: Tensor had NaN values" in e.message

    if int_labels is True:
      _labels = tf.cast(_labels, tf.int32, "label_int")

    if reshape_to is not None:
      _labels = tf.reshape(_labels, reshape_to)
  
    return features, _labels
  
  # get files
  ds = tf.data.Dataset.list_files(str(pathlib.Path(filepaths)/'*.csv'))
  # read in random order cycling through files
  ds = ds.interleave(
      lambda filepath: tf.data.TextLineDataset(filepath).skip(1),
      cycle_length=n_readers, num_parallel_calls=n_read_threads
  )
  # shuffle and repeat
  ds = ds.shuffle(shuffle_buffer_size).repeat(repeat)
  # preprocess dataset (must provide a function)
  ds = ds.map(get_features_labels, num_parallel_calls=n_parse_threads)
  # cache dataset
  ds = ds.cache()
  ds = ds.batch(batch_size)
  ds = ds.prefetch(1)
  return ds

# %%
import json
def save_model_info(dir, features, labels, scales=[]):
  model_info = {"features": features, "labels": labels, "scales": scales}
  model_info = json.dumps(model_info)
  if not os.path.exists(dir):
    os.makedirs(dir)
  with open(dir/"info.json", "w") as jsonfile:
    jsonfile.write(model_info)

# %%
import tensorflow as tf
import matplotlib 
import matplotlib.pyplot as plt

def scatter_accuracy(ys, preds):
  try:
    if ys.shape != preds.shape:
      ys = tf.reshape(ys, preds.shape)
    e = abs(ys - preds)
    fig, ax = plt.subplots(figsize=(10,10))
    cb = ax.scatter(ys, preds, c=e, cmap="jet")
    ax.grid()
    ax.set_ylabel("Predicted")
    ax.set_xlabel("True")
    ax.set_title("Accuracy scatter plot")
    fig.colorbar(cb, ax=ax)
  except:
    print("Failed generating scatter plot.")

# %% [markdown]
# # Model features and labels

# %%
MODEL_PREFIX = "PAT_GAMMA_REGRESSOR"

# %%
FEATS = ["endo", "epi", "pressure", "volume"]
LABELS = ["gamma",]
BIN_LABELS = [k + "-b" for k in FEATS if k+"-b" in header.keys()]
FEATS, BIN_LABELS, LABELS
# Out:
# (['endo', 'epi', 'pressure', 'volume'],
#  ['endo-b', 'epi-b', 'pressure-b', 'volume-b'],
#  ['gamma'])

# %% [markdown]
# # Gamma Regressor with 4 inputs

# %%
gm4_save_root = model_save_root/MODEL_PREFIX.upper()
gm4_best_save = gm4_save_root/"best"
gm4_best_save_weights = gm4_best_save/"weights"

# %% [markdown]
# ## Load Gamma Dataset
#
# Labels: ['gamma']
#
# Features: ['epi', 'endo', 'pressure', 'volume']

# %%
BATCH_SIZE = 500
gm4_ds_train = csv_ds_reader(train_dir, header, LABELS, FEATS, batch_size=BATCH_SIZE)
gm4_ds_valid = csv_ds_reader(valid_dir, header, LABELS, FEATS, batch_size=BATCH_SIZE)
gm4_ds_test  = csv_ds_reader(test_dir,  header, LABELS, FEATS, batch_size=BATCH_SIZE)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
LABELS
# Out:
# ['gamma']

# %%
print("CM4 train set:")
for (features, labels) in gm4_ds_train.take(1):
  print("Features: {} \nLabels: {}".format(features[0], labels[0]))
  print("Shapes -> Features: {}, Labels: {}".format(features.shape, labels.shape))
# Out:
# CM4 train set:
# Features: [40.00000 -44.00000 0.50000 0.55325]
# Labels: [0.25800]
# Shapes -> Features: (500, 4), Labels: (500, 1)

# %% [markdown]
# ### Normalization Layer

# %%
GAMMA_NormLayer = build_norm_layer(1000, header, LABELS, FEATS, MODEL_PREFIX+"_norm")

# %% [markdown]
# ### Arquitecture

# %%
GAMMA_R = GAMMA_Regressor_Model(50, 1, GAMMA_NormLayer, len(LABELS))
GAMMA_R.build([None, len(FEATS)])
GAMMA_R.summary()
# Out:
# Model: "gamma__regressor__model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  PAT_GAMMA_REGRESSOR_norm (N  multiple                 9
#  ormalization)
#
#  dense (Dense)               multiple                  250
#
#  resnet_block (ResnetBlock)  multiple                  7650
#
#  resnet_block_1 (ResnetBlock  multiple                 0 (unused)
#  )
#
#  resnet_block_2 (ResnetBlock  multiple                 0 (unused)
#  )
#
#  dense_10 (Dense)            multiple                  5100
#
#  dense_11 (Dense)            multiple                  20200
#
#  activity_regularization (Ac  multiple                 0
#  tivityRegularization)
#
#  gr_body_out (Dense)         multiple                  201
#
# =================================================================
# Total params: 33,410
# Trainable params: 33,401
# Non-trainable params: 9
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
initial_learning_rate = 1e-4
GAMMA_ROptimizer = tf.keras.optimizers.Adam(learning_rate=initial_learning_rate)
GAMMA_RLoss = tf.keras.losses.MeanSquaredError()
GAMMA_R.compile(
    loss = [GAMMA_RLoss],# tf.keras.losses.MeanSquaredLogarithmicError()],
    optimizer=GAMMA_ROptimizer,
    metrics=["mse", "mae", tf.keras.metrics.RootMeanSquaredError()]
)

# %%
GAMMA_RCallbacks = [
  tf.keras.callbacks.ReduceLROnPlateau(factor=0.7, patience=3, verbose=1),
  tf.keras.callbacks.EarlyStopping(patience=6, verbose=1, restore_best_weights=True),
]

# %%
with tf.device('/device:GPU:0'):
  gm4_TrainHistory = GAMMA_R.fit(
    gm4_ds_train,
    epochs=300, verbose=1, 
    validation_data=gm4_ds_valid,
    callbacks=GAMMA_RCallbacks
  )
# Out:
# Epoch 1/300
# 867/867 [==============================] - 130s 141ms/step - loss: 0.0021 - mse: 0.0013 - mae: 0.0217 - root_mean_squared_error: 0.0354 - val_loss: 6.7278e-04 - val_mse: 2.2043e-04 - val_mae: 0.0109 - val_root_mean_squared_error: 0.0148 - lr: 1.0000e-04
# Epoch 2/300
# 867/867 [==============================] - 6s 7ms/step - loss: 4.6776e-04 - mse: 1.9056e-04 - mae: 0.0097 - root_mean_squared_error: 0.0138 - val_loss: 3.4053e-04 - val_mse: 1.5281e-04 - val_mae: 0.0085 - val_root_mean_squared_error: 0.0124 - lr: 1.0000e-04
# Epoch 3/300
# 867/867 [==============================] - 5s 6ms/step - loss: 3.0809e-04 - mse: 1.4870e-04 - mae: 0.0081 - root_mean_squared_error: 0.0122 - val_loss: 2.6827e-04 - val_mse: 1.2844e-04 - val_mae: 0.0074 - val_root_mean_squared_error: 0.0113 - lr: 1.0000e-04
# Epoch 4/300
# 867/867 [==============================] - 6s 6ms/step - loss: 2.5746e-04 - mse: 1.3078e-04 - mae: 0.0074 - root_mean_squared_error: 0.0114 - val_loss: 2.3274e-04 - val_mse: 1.1760e-04 - val_mae: 0.0069 - val_root_mean_squared_error: 0.0108 - lr: 1.0000e-04
# Epoch 5/300
# 867/867 [==============================] - 6s 7ms/step - loss: 2.2526e-04 - mse: 1.2034e-04 - mae: 0.0069 - root_mean_squared_error: 0.0110 - val_loss: 2.0472e-04 - val_mse: 1.0934e-04 - val_mae: 0.0065 - val_root_mean_squared_error: 0.0105 - lr: 1.0000e-04
# Epoch 6/300
# 867/867 [==============================] - 7s 8ms/step - loss: 1.9937e-04 - mse: 1.1206e-04 - mae: 0.0066 - root_mean_squared_error: 0.0106 - val_loss: 1.8222e-04 - val_mse: 1.0219e-04 - val_mae: 0.0062 - val_root_mean_squared_error: 0.0101 - lr: 1.0000e-04
# Epoch 7/300
# 865/867 [============================>.] - ETA: 0s - loss: 1.7855e-04 - mse: 1.0503e-04 - mae: 0.0063 - root_mean_squared_error: 0.0102
# Epoch 7: ReduceLROnPlateau reducing learning rate to 6.999999823165126e-05.
# 867/867 [==============================] - 6s 7ms/step - loss: 1.7855e-04 - mse: 1.0504e-04 - mae: 0.0063 - root_mean_squared_error: 0.0102 - val_loss: 1.6367e-04 - val_mse: 9.6014e-05 - val_mae: 0.0060 - val_root_mean_squared_error: 0.0098 - lr: 1.0000e-04
# Epoch 8/300
# 867/867 [==============================] - 6s 7ms/step - loss: 1.6214e-04 - mse: 9.8306e-05 - mae: 0.0060 - root_mean_squared_error: 0.0099 - val_loss: 1.5077e-04 - val_mse: 9.0500e-05 - val_mae: 0.0057 - val_root_mean_squared_error: 0.0095 - lr: 7.0000e-05
# Epoch 9/300
# 867/867 [==============================] - 6s 7ms/step - loss: 1.5053e-04 - mse: 9.3705e-05 - mae: 0.0058 - root_mean_squared_error: 0.0097 - val_loss: 1.3990e-04 - val_mse: 8.6277e-05 - val_mae: 0.0055 - val_root_mean_squared_error: 0.0093 - lr: 7.0000e-05
# Epoch 10/300
# 867/867 [==============================] - 6s 7ms/step - loss: 1.3968e-04 - mse: 8.9112e-05 - mae: 0.0057 - root_mean_squared_error: 0.0094 - val_loss: 1.2969e-04 - val_mse: 8.1839e-05 - val_mae: 0.0054 - val_root_mean_squared_error: 0.0090 - lr: 7.0000e-05
# Epoch 11/300
# 867/867 [==============================] - 6s 7ms/step - loss: 1.2990e-04 - mse: 8.4727e-05 - mae: 0.0055 - root_mean_squared_error: 0.0092 - val_loss: 1.2031e-04 - val_mse: 7.7503e-05 - val_mae: 0.0052 - val_root_mean_squared_error: 0.0088 - lr: 7.0000e-05
# Epoch 12/300
# 867/867 [==============================] - 7s 8ms/step - loss: 1.2094e-04 - mse: 8.0480e-05 - mae: 0.0054 - root_mean_squared_error: 0.0090 - val_loss: 1.1160e-04 - val_mse: 7.3231e-05 - val_mae: 0.0051 - val_root_mean_squared_error: 0.0086 - lr: 7.0000e-05
# Epoch 13/300
# 860/867 [============================>.] - ETA: 0s - loss: 1.1297e-04 - mse: 7.6515e-05 - mae: 0.0052 - root_mean_squared_error: 0.0087
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.899999621557071e-05.
# 867/867 [==============================] - 6s 6ms/step - loss: 1.1295e-04 - mse: 7.6498e-05 - mae: 0.0052 - root_mean_squared_error: 0.0087 - val_loss: 1.0426e-04 - val_mse: 6.9475e-05 - val_mae: 0.0050 - val_root_mean_squared_error: 0.0083 - lr: 7.0000e-05
# Epoch 14/300
# 867/867 [==============================] - 6s 6ms/step - loss: 1.0638e-04 - mse: 7.2773e-05 - mae: 0.0051 - root_mean_squared_error: 0.0085 - val_loss: 9.9286e-05 - val_mse: 6.6589e-05 - val_mae: 0.0048 - val_root_mean_squared_error: 0.0082 - lr: 4.9000e-05
# Epoch 15/300
# 867/867 [==============================] - 6s 7ms/step - loss: 1.0197e-04 - mse: 7.0371e-05 - mae: 0.0050 - root_mean_squared_error: 0.0084 - val_loss: 9.5232e-05 - val_mse: 6.4406e-05 - val_mae: 0.0048 - val_root_mean_squared_error: 0.0080 - lr: 4.9000e-05
# Epoch 16/300
# 863/867 [============================>.] - ETA: 0s - loss: 9.7837e-05 - mse: 6.8046e-05 - mae: 0.0049 - root_mean_squared_error: 0.0082
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.4299996332265434e-05.
# 867/867 [==============================] - 6s 7ms/step - loss: 9.7853e-05 - mse: 6.8064e-05 - mae: 0.0049 - root_mean_squared_error: 0.0083 - val_loss: 9.1383e-05 - val_mse: 6.2322e-05 - val_mae: 0.0047 - val_root_mean_squared_error: 0.0079 - lr: 4.9000e-05
# Epoch 17/300
# 867/867 [==============================] - 7s 7ms/step - loss: 9.4411e-05 - mse: 6.5995e-05 - mae: 0.0048 - root_mean_squared_error: 0.0081 - val_loss: 8.8430e-05 - val_mse: 6.0560e-05 - val_mae: 0.0046 - val_root_mean_squared_error: 0.0078 - lr: 3.4300e-05
# Epoch 18/300
# 867/867 [==============================] - 6s 6ms/step - loss: 9.2245e-05 - mse: 6.4875e-05 - mae: 0.0048 - root_mean_squared_error: 0.0081 - val_loss: 8.6061e-05 - val_mse: 5.9165e-05 - val_mae: 0.0045 - val_root_mean_squared_error: 0.0077 - lr: 3.4300e-05
# Epoch 19/300
# 862/867 [============================>.] - ETA: 0s - loss: 8.9999e-05 - mse: 6.3588e-05 - mae: 0.0048 - root_mean_squared_error: 0.0080
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.400999692326877e-05.
# 867/867 [==============================] - 7s 8ms/step - loss: 9.0027e-05 - mse: 6.3618e-05 - mae: 0.0048 - root_mean_squared_error: 0.0080 - val_loss: 8.3967e-05 - val_mse: 5.8073e-05 - val_mae: 0.0045 - val_root_mean_squared_error: 0.0076 - lr: 3.4300e-05
# Epoch 20/300
# 867/867 [==============================] - 6s 6ms/step - loss: 8.7677e-05 - mse: 6.2028e-05 - mae: 0.0047 - root_mean_squared_error: 0.0079 - val_loss: 8.2216e-05 - val_mse: 5.6862e-05 - val_mae: 0.0044 - val_root_mean_squared_error: 0.0075 - lr: 2.4010e-05
# Epoch 21/300
# 867/867 [==============================] - 6s 7ms/step - loss: 8.6396e-05 - mse: 6.1334e-05 - mae: 0.0047 - root_mean_squared_error: 0.0078 - val_loss: 8.0894e-05 - val_mse: 5.6172e-05 - val_mae: 0.0044 - val_root_mean_squared_error: 0.0075 - lr: 2.4010e-05
# Epoch 22/300
# 864/867 [============================>.] - ETA: 0s - loss: 8.5023e-05 - mse: 6.0540e-05 - mae: 0.0046 - root_mean_squared_error: 0.0078
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.6806997336971108e-05.
# 867/867 [==============================] - 6s 7ms/step - loss: 8.5025e-05 - mse: 6.0543e-05 - mae: 0.0046 - root_mean_squared_error: 0.0078 - val_loss: 7.9526e-05 - val_mse: 5.5369e-05 - val_mae: 0.0044 - val_root_mean_squared_error: 0.0074 - lr: 2.4010e-05
# Epoch 23/300
# 867/867 [==============================] - 7s 8ms/step - loss: 8.3698e-05 - mse: 5.9694e-05 - mae: 0.0046 - root_mean_squared_error: 0.0077 - val_loss: 7.8368e-05 - val_mse: 5.4599e-05 - val_mae: 0.0044 - val_root_mean_squared_error: 0.0074 - lr: 1.6807e-05
# Epoch 24/300
# 867/867 [==============================] - 6s 7ms/step - loss: 8.2549e-05 - mse: 5.8922e-05 - mae: 0.0046 - root_mean_squared_error: 0.0077 - val_loss: 7.7556e-05 - val_mse: 5.4189e-05 - val_mae: 0.0043 - val_root_mean_squared_error: 0.0074 - lr: 1.6807e-05
# Epoch 25/300
# 865/867 [============================>.] - ETA: 0s - loss: 8.1813e-05 - mse: 5.8556e-05 - mae: 0.0046 - root_mean_squared_error: 0.0077
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.1764897499233484e-05.
# 867/867 [==============================] - 7s 8ms/step - loss: 8.1814e-05 - mse: 5.8556e-05 - mae: 0.0046 - root_mean_squared_error: 0.0077 - val_loss: 7.6668e-05 - val_mse: 5.3606e-05 - val_mae: 0.0043 - val_root_mean_squared_error: 0.0073 - lr: 1.6807e-05
# Epoch 26/300
# 867/867 [==============================] - 6s 7ms/step - loss: 8.0639e-05 - mse: 5.7664e-05 - mae: 0.0045 - root_mean_squared_error: 0.0076 - val_loss: 7.5910e-05 - val_mse: 5.3100e-05 - val_mae: 0.0043 - val_root_mean_squared_error: 0.0073 - lr: 1.1765e-05
# Epoch 27/300
# 867/867 [==============================] - 6s 7ms/step - loss: 8.0231e-05 - mse: 5.7498e-05 - mae: 0.0045 - root_mean_squared_error: 0.0076 - val_loss: 7.5229e-05 - val_mse: 5.2662e-05 - val_mae: 0.0043 - val_root_mean_squared_error: 0.0073 - lr: 1.1765e-05
# Epoch 28/300
# 865/867 [============================>.] - ETA: 0s - loss: 7.9996e-05 - mse: 5.7491e-05 - mae: 0.0045 - root_mean_squared_error: 0.0076
# Epoch 28: ReduceLROnPlateau reducing learning rate to 8.235428504121954e-06.
# 867/867 [==============================] - 6s 7ms/step - loss: 8.0004e-05 - mse: 5.7499e-05 - mae: 0.0045 - root_mean_squared_error: 0.0076 - val_loss: 7.4754e-05 - val_mse: 5.2415e-05 - val_mae: 0.0043 - val_root_mean_squared_error: 0.0072 - lr: 1.1765e-05
# Epoch 29/300
# 867/867 [==============================] - 7s 8ms/step - loss: 7.9012e-05 - mse: 5.6688e-05 - mae: 0.0045 - root_mean_squared_error: 0.0075 - val_loss: 7.4163e-05 - val_mse: 5.1968e-05 - val_mae: 0.0043 - val_root_mean_squared_error: 0.0072 - lr: 8.2354e-06
# Epoch 30/300
# 867/867 [==============================] - 6s 6ms/step - loss: 7.8681e-05 - mse: 5.6517e-05 - mae: 0.0045 - root_mean_squared_error: 0.0075 - val_loss: 7.3770e-05 - val_mse: 5.1719e-05 - val_mae: 0.0043 - val_root_mean_squared_error: 0.0072 - lr: 8.2354e-06
# Epoch 31/300
# 865/867 [============================>.] - ETA: 0s - loss: 7.8232e-05 - mse: 5.6226e-05 - mae: 0.0045 - root_mean_squared_error: 0.0075
# Epoch 31: ReduceLROnPlateau reducing learning rate to 5.764799698226852e-06.
# 867/867 [==============================] - 7s 8ms/step - loss: 7.8233e-05 - mse: 5.6227e-05 - mae: 0.0045 - root_mean_squared_error: 0.0075 - val_loss: 7.3417e-05 - val_mse: 5.1515e-05 - val_mae: 0.0043 - val_root_mean_squared_error: 0.0072 - lr: 8.2354e-06
# Epoch 32/300
# 867/867 [==============================] - 6s 6ms/step - loss: 7.7876e-05 - mse: 5.5999e-05 - mae: 0.0044 - root_mean_squared_error: 0.0075 - val_loss: 7.3057e-05 - val_mse: 5.1246e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0072 - lr: 5.7648e-06
# Epoch 33/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.7601e-05 - mse: 5.5825e-05 - mae: 0.0044 - root_mean_squared_error: 0.0075 - val_loss: 7.2794e-05 - val_mse: 5.1062e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 5.7648e-06
# Epoch 34/300
# 864/867 [============================>.] - ETA: 0s - loss: 7.7280e-05 - mse: 5.5604e-05 - mae: 0.0044 - root_mean_squared_error: 0.0075
# Epoch 34: ReduceLROnPlateau reducing learning rate to 4.035359916088054e-06.
# 867/867 [==============================] - 7s 8ms/step - loss: 7.7281e-05 - mse: 5.5605e-05 - mae: 0.0044 - root_mean_squared_error: 0.0075 - val_loss: 7.2545e-05 - val_mse: 5.0928e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 5.7648e-06
# Epoch 35/300
# 867/867 [==============================] - 6s 6ms/step - loss: 7.7104e-05 - mse: 5.5518e-05 - mae: 0.0044 - root_mean_squared_error: 0.0075 - val_loss: 7.2310e-05 - val_mse: 5.0765e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 4.0354e-06
# Epoch 36/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.6890e-05 - mse: 5.5376e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.2134e-05 - val_mse: 5.0659e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 4.0354e-06
# Epoch 37/300
# 867/867 [==============================] - ETA: 0s - loss: 7.6391e-05 - mse: 5.4945e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 37: ReduceLROnPlateau reducing learning rate to 2.8247518457646947e-06.
# 867/867 [==============================] - 7s 8ms/step - loss: 7.6391e-05 - mse: 5.4945e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.1968e-05 - val_mse: 5.0572e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 4.0354e-06
# Epoch 38/300
# 867/867 [==============================] - 6s 6ms/step - loss: 7.6481e-05 - mse: 5.5094e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.1816e-05 - val_mse: 5.0469e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 2.8248e-06
# Epoch 39/300
# 867/867 [==============================] - 6s 6ms/step - loss: 7.6146e-05 - mse: 5.4808e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.1672e-05 - val_mse: 5.0357e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 2.8248e-06
# Epoch 40/300
# 866/867 [============================>.] - ETA: 0s - loss: 7.6159e-05 - mse: 5.4864e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.9773262920352863e-06.
# 867/867 [==============================] - 6s 6ms/step - loss: 7.6151e-05 - mse: 5.4857e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.1583e-05 - val_mse: 5.0322e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 2.8248e-06
# Epoch 41/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.6174e-05 - mse: 5.4920e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.1496e-05 - val_mse: 5.0262e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.9773e-06
# Epoch 42/300
# 867/867 [==============================] - 6s 6ms/step - loss: 7.6343e-05 - mse: 5.5123e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.1400e-05 - val_mse: 5.0209e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.9773e-06
# Epoch 43/300
# 863/867 [============================>.] - ETA: 0s - loss: 7.5933e-05 - mse: 5.4747e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.3841284044247003e-06.
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5957e-05 - mse: 5.4771e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.1321e-05 - val_mse: 5.0164e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.9773e-06
# Epoch 44/300
# 867/867 [==============================] - 7s 9ms/step - loss: 7.5872e-05 - mse: 5.4714e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.1247e-05 - val_mse: 5.0103e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.3841e-06
# Epoch 45/300
# 867/867 [==============================] - 6s 6ms/step - loss: 7.5528e-05 - mse: 5.4390e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.1193e-05 - val_mse: 5.0085e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.3841e-06
# Epoch 46/300
# 860/867 [============================>.] - ETA: 0s - loss: 7.5814e-05 - mse: 5.4704e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 46: ReduceLROnPlateau reducing learning rate to 9.68889867181133e-07.
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5814e-05 - mse: 5.4703e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.1144e-05 - val_mse: 5.0057e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.3841e-06
# Epoch 47/300
# 867/867 [==============================] - 5s 6ms/step - loss: 7.5667e-05 - mse: 5.4576e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.1094e-05 - val_mse: 5.0029e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 9.6889e-07
# Epoch 48/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5680e-05 - mse: 5.4604e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.1057e-05 - val_mse: 5.0006e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 9.6889e-07
# Epoch 49/300
# 867/867 [==============================] - ETA: 0s - loss: 7.5497e-05 - mse: 5.4437e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.782228751944785e-07.
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5497e-05 - mse: 5.4437e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.1009e-05 - val_mse: 4.9971e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 9.6889e-07
# Epoch 50/300
# 867/867 [==============================] - 8s 9ms/step - loss: 7.5323e-05 - mse: 5.4278e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0985e-05 - val_mse: 4.9961e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 6.7822e-07
# Epoch 51/300
# 867/867 [==============================] - 11s 13ms/step - loss: 7.5465e-05 - mse: 5.4427e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0962e-05 - val_mse: 4.9946e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 6.7822e-07
# Epoch 52/300
# 863/867 [============================>.] - ETA: 0s - loss: 7.5521e-05 - mse: 5.4497e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 52: ReduceLROnPlateau reducing learning rate to 4.7475601263613496e-07.
# 867/867 [==============================] - 10s 11ms/step - loss: 7.5521e-05 - mse: 5.4496e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0933e-05 - val_mse: 4.9931e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 6.7822e-07
# Epoch 53/300
# 867/867 [==============================] - 7s 8ms/step - loss: 7.5476e-05 - mse: 5.4458e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0915e-05 - val_mse: 4.9917e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 4.7476e-07
# Epoch 54/300
# 867/867 [==============================] - 6s 6ms/step - loss: 7.5679e-05 - mse: 5.4671e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0897e-05 - val_mse: 4.9911e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 4.7476e-07
# Epoch 55/300
# 863/867 [============================>.] - ETA: 0s - loss: 7.5288e-05 - mse: 5.4290e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 55: ReduceLROnPlateau reducing learning rate to 3.323292048662551e-07.
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5293e-05 - mse: 5.4295e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0873e-05 - val_mse: 4.9889e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 4.7476e-07
# Epoch 56/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5544e-05 - mse: 5.4552e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0865e-05 - val_mse: 4.9887e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 3.3233e-07
# Epoch 57/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5322e-05 - mse: 5.4334e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0851e-05 - val_mse: 4.9879e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 3.3233e-07
# Epoch 58/300
# 865/867 [============================>.] - ETA: 0s - loss: 7.5514e-05 - mse: 5.4531e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 58: ReduceLROnPlateau reducing learning rate to 2.3263043544829997e-07.
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5517e-05 - mse: 5.4533e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0834e-05 - val_mse: 4.9870e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 3.3233e-07
# Epoch 59/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5447e-05 - mse: 5.4468e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0828e-05 - val_mse: 4.9867e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 2.3263e-07
# Epoch 60/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5224e-05 - mse: 5.4251e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0816e-05 - val_mse: 4.9858e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 2.3263e-07
# Epoch 61/300
# 863/867 [============================>.] - ETA: 0s - loss: 7.5440e-05 - mse: 5.4471e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1.6284130879284928e-07.
# 867/867 [==============================] - 7s 8ms/step - loss: 7.5450e-05 - mse: 5.4480e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0808e-05 - val_mse: 4.9854e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 2.3263e-07
# Epoch 62/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5196e-05 - mse: 5.4228e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0798e-05 - val_mse: 4.9842e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.6284e-07
# Epoch 63/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5311e-05 - mse: 5.4345e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0793e-05 - val_mse: 4.9840e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.6284e-07
# Epoch 64/300
# 858/867 [============================>.] - ETA: 0s - loss: 7.5523e-05 - mse: 5.4563e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.1398891217595519e-07.
# 867/867 [==============================] - 7s 8ms/step - loss: 7.5508e-05 - mse: 5.4546e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0790e-05 - val_mse: 4.9842e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.6284e-07
# Epoch 65/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5481e-05 - mse: 5.4520e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0782e-05 - val_mse: 4.9832e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.1399e-07
# Epoch 66/300
# 867/867 [==============================] - 8s 9ms/step - loss: 7.5198e-05 - mse: 5.4240e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0781e-05 - val_mse: 4.9840e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.1399e-07
# Epoch 67/300
# 866/867 [============================>.] - ETA: 0s - loss: 7.5211e-05 - mse: 5.4258e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 67: ReduceLROnPlateau reducing learning rate to 7.97922375284088e-08.
# 867/867 [==============================] - 6s 6ms/step - loss: 7.5204e-05 - mse: 5.4250e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0775e-05 - val_mse: 4.9830e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.1399e-07
# Epoch 68/300
# 867/867 [==============================] - 7s 8ms/step - loss: 7.5396e-05 - mse: 5.4442e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0771e-05 - val_mse: 4.9828e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 7.9792e-08
# Epoch 69/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5250e-05 - mse: 5.4299e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0768e-05 - val_mse: 4.9826e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 7.9792e-08
# Epoch 70/300
# 862/867 [============================>.] - ETA: 0s - loss: 7.5218e-05 - mse: 5.4266e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 70: ReduceLROnPlateau reducing learning rate to 5.585456577250625e-08.
# 867/867 [==============================] - 7s 8ms/step - loss: 7.5218e-05 - mse: 5.4266e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0765e-05 - val_mse: 4.9827e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 7.9792e-08
# Epoch 71/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5172e-05 - mse: 5.4224e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0762e-05 - val_mse: 4.9822e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 5.5855e-08
# Epoch 72/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5071e-05 - mse: 5.4121e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0762e-05 - val_mse: 4.9824e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 5.5855e-08
# Epoch 73/300
# 863/867 [============================>.] - ETA: 0s - loss: 7.5233e-05 - mse: 5.4283e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 73: ReduceLROnPlateau reducing learning rate to 3.90981970355142e-08.
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5248e-05 - mse: 5.4299e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0758e-05 - val_mse: 4.9821e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 5.5855e-08
# Epoch 74/300
# 867/867 [==============================] - 6s 6ms/step - loss: 7.5265e-05 - mse: 5.4317e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0756e-05 - val_mse: 4.9820e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 3.9098e-08
# Epoch 75/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5149e-05 - mse: 5.4201e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0755e-05 - val_mse: 4.9819e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 3.9098e-08
# Epoch 76/300
# 861/867 [============================>.] - ETA: 0s - loss: 7.5160e-05 - mse: 5.4214e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 76: ReduceLROnPlateau reducing learning rate to 2.7368737676169985e-08.
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5174e-05 - mse: 5.4227e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0753e-05 - val_mse: 4.9817e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 3.9098e-08
# Epoch 77/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5496e-05 - mse: 5.4547e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0753e-05 - val_mse: 4.9818e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 2.7369e-08
# Epoch 78/300
# 867/867 [==============================] - 6s 6ms/step - loss: 7.5286e-05 - mse: 5.4339e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0752e-05 - val_mse: 4.9817e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 2.7369e-08
# Epoch 79/300
# 866/867 [============================>.] - ETA: 0s - loss: 7.5349e-05 - mse: 5.4402e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.9158116870698905e-08.
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5340e-05 - mse: 5.4393e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0750e-05 - val_mse: 4.9816e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 2.7369e-08
# Epoch 80/300
# 867/867 [==============================] - 7s 8ms/step - loss: 7.5350e-05 - mse: 5.4405e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0750e-05 - val_mse: 4.9815e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.9158e-08
# Epoch 81/300
# 867/867 [==============================] - 6s 6ms/step - loss: 7.5351e-05 - mse: 5.4403e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0750e-05 - val_mse: 4.9816e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.9158e-08
# Epoch 82/300
# 864/867 [============================>.] - ETA: 0s - loss: 7.5341e-05 - mse: 5.4397e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 82: ReduceLROnPlateau reducing learning rate to 1.3410681809489232e-08.
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5341e-05 - mse: 5.4397e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0749e-05 - val_mse: 4.9814e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.9158e-08
# Epoch 83/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5372e-05 - mse: 5.4427e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0748e-05 - val_mse: 4.9814e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.3411e-08
# Epoch 84/300
# 867/867 [==============================] - 6s 6ms/step - loss: 7.5155e-05 - mse: 5.4208e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0748e-05 - val_mse: 4.9814e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.3411e-08
# Epoch 85/300
# 858/867 [============================>.] - ETA: 0s - loss: 7.5111e-05 - mse: 5.4170e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 85: ReduceLROnPlateau reducing learning rate to 9.387477017952506e-09.
# 867/867 [==============================] - 5s 6ms/step - loss: 7.5107e-05 - mse: 5.4164e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0748e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.3411e-08
# Epoch 86/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5250e-05 - mse: 5.4304e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0748e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 9.3875e-09
# Epoch 87/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5176e-05 - mse: 5.4231e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 9.3875e-09
# Epoch 88/300
# 858/867 [============================>.] - ETA: 0s - loss: 7.5289e-05 - mse: 5.4344e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 88: ReduceLROnPlateau reducing learning rate to 6.5712342234292e-09.
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5290e-05 - mse: 5.4343e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 9.3875e-09
# Epoch 89/300
# 867/867 [==============================] - 7s 8ms/step - loss: 7.5401e-05 - mse: 5.4456e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 6.5712e-09
# Epoch 90/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5318e-05 - mse: 5.4372e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 6.5712e-09
# Epoch 91/300
# 860/867 [============================>.] - ETA: 0s - loss: 7.5115e-05 - mse: 5.4169e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 91: ReduceLROnPlateau reducing learning rate to 4.59986395640044e-09.
# 867/867 [==============================] - 7s 8ms/step - loss: 7.5094e-05 - mse: 5.4148e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 6.5712e-09
# Epoch 92/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5266e-05 - mse: 5.4321e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 4.5999e-09
# Epoch 93/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5110e-05 - mse: 5.4165e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 4.5999e-09
# Epoch 94/300
# 867/867 [==============================] - ETA: 0s - loss: 7.5328e-05 - mse: 5.4383e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 94: ReduceLROnPlateau reducing learning rate to 3.2199048316527977e-09.
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5328e-05 - mse: 5.4383e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 4.5999e-09
# Epoch 95/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5355e-05 - mse: 5.4408e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 3.2199e-09
# Epoch 96/300
# 867/867 [==============================] - 6s 6ms/step - loss: 7.5174e-05 - mse: 5.4228e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 3.2199e-09
# Epoch 97/300
# 863/867 [============================>.] - ETA: 0s - loss: 7.5277e-05 - mse: 5.4332e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 97: ReduceLROnPlateau reducing learning rate to 2.2539333510707135e-09.
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5309e-05 - mse: 5.4365e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 3.2199e-09
# Epoch 98/300
# 867/867 [==============================] - 6s 6ms/step - loss: 7.5336e-05 - mse: 5.4390e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 2.2539e-09
# Epoch 99/300
# 867/867 [==============================] - 7s 8ms/step - loss: 7.5218e-05 - mse: 5.4273e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 2.2539e-09
# Epoch 100/300
# 862/867 [============================>.] - ETA: 0s - loss: 7.5307e-05 - mse: 5.4362e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 100: ReduceLROnPlateau reducing learning rate to 1.5777532835770102e-09.
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5326e-05 - mse: 5.4381e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 2.2539e-09
# Epoch 101/300
# 867/867 [==============================] - 7s 8ms/step - loss: 7.5364e-05 - mse: 5.4421e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.5778e-09
# Epoch 102/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5107e-05 - mse: 5.4162e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.5778e-09
# Epoch 103/300
# 860/867 [============================>.] - ETA: 0s - loss: 7.5233e-05 - mse: 5.4288e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 103: ReduceLROnPlateau reducing learning rate to 1.1044272829607848e-09.
# 867/867 [==============================] - 7s 8ms/step - loss: 7.5216e-05 - mse: 5.4271e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.5778e-09
# Epoch 104/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5302e-05 - mse: 5.4358e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.1044e-09
# Epoch 105/300
# 867/867 [==============================] - 6s 6ms/step - loss: 7.5228e-05 - mse: 5.4282e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.1044e-09
# Epoch 106/300
# 866/867 [============================>.] - ETA: 0s - loss: 7.5195e-05 - mse: 5.4250e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 106: ReduceLROnPlateau reducing learning rate to 7.73099129158794e-10.
# 867/867 [==============================] - 6s 6ms/step - loss: 7.5191e-05 - mse: 5.4246e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 1.1044e-09
# Epoch 107/300
# 867/867 [==============================] - 7s 8ms/step - loss: 7.5302e-05 - mse: 5.4356e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 7.7310e-10
# Epoch 108/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.4989e-05 - mse: 5.4044e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 7.7310e-10
# Epoch 109/300
# 865/867 [============================>.] - ETA: 0s - loss: 7.5222e-05 - mse: 5.4276e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 109: ReduceLROnPlateau reducing learning rate to 5.41169398182717e-10.
# 867/867 [==============================] - 7s 8ms/step - loss: 7.5230e-05 - mse: 5.4283e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 7.7310e-10
# Epoch 110/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5350e-05 - mse: 5.4405e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 5.4117e-10
# Epoch 111/300
# 867/867 [==============================] - 7s 8ms/step - loss: 7.5171e-05 - mse: 5.4227e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 5.4117e-10
# Epoch 112/300
# 863/867 [============================>.] - ETA: 0s - loss: 7.5341e-05 - mse: 5.4394e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074
# Epoch 112: ReduceLROnPlateau reducing learning rate to 3.788185709563407e-10.
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5362e-05 - mse: 5.4415e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 5.4117e-10
# Epoch 113/300
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5493e-05 - mse: 5.4548e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 3.7882e-10
# Epoch 114/300
# 867/867 [==============================] - ETA: 0s - loss: 7.5280e-05 - mse: 5.4337e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074Restoring model weights from the end of the best epoch: 108.
# 867/867 [==============================] - 6s 7ms/step - loss: 7.5280e-05 - mse: 5.4337e-05 - mae: 0.0044 - root_mean_squared_error: 0.0074 - val_loss: 7.0747e-05 - val_mse: 4.9813e-05 - val_mae: 0.0042 - val_root_mean_squared_error: 0.0071 - lr: 3.7882e-10
# Epoch 114: early stopping

# %%
GAMMA_RTrainHistDf = pd.DataFrame(gm4_TrainHistory.history)
GAMMA_RTrainHistDf.plot(figsize=(12,15), logy=True, logx=True)
plt.grid(True)
plt.gca().set_ylim(0,GAMMA_RTrainHistDf.values.max())
plt.show()
# Out:
# <ipython-input-25-a60ae996d876>:4: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.gca().set_ylim(0,GAMMA_RTrainHistDf.values.max())

# %% [markdown]
# ## Testing

# %%
GAMMA_R.evaluate(gm4_ds_test)
# Out:
# 232/232 [==============================] - 50s 197ms/step - loss: 7.0904e-05 - mse: 5.0039e-05 - mae: 0.0042 - root_mean_squared_error: 0.0071
# [7.090445433277637e-05,
#  5.0039041525451466e-05,
#  0.004183936398476362,
#  0.0070738280192017555]

# %%
n_print = 20

for (xs, ys) in gm4_ds_test.take(1):
  preds = GAMMA_R.predict(xs)
  for i in range(n_print):
    # print("Inputs: {}".format(xs[i]))
    print("True: {} | Pred: {}".format(ys[i], preds[i]))
    # print("-"*10)
# Out:
# 16/16 [==============================] - 0s 2ms/step
# True: [0.15600] | Pred: [0.15328]
# True: [0.13800] | Pred: [0.14335]
# True: [0.23400] | Pred: [0.23900]
# True: [0.16800] | Pred: [0.17985]
# True: [0.13200] | Pred: [0.13368]
# True: [0.21600] | Pred: [0.21407]
# True: [0.25200] | Pred: [0.26554]
# True: [0.27000] | Pred: [0.26420]
# True: [0.24600] | Pred: [0.24743]
# True: [0.13200] | Pred: [0.13143]
# True: [0.13200] | Pred: [0.13446]
# True: [0.21000] | Pred: [0.21455]
# True: [0.17400] | Pred: [0.17626]
# True: [0.30000] | Pred: [0.28684]
# True: [0.14400] | Pred: [0.14901]
# True: [0.13200] | Pred: [0.12652]
# True: [0.24600] | Pred: [0.24452]
# True: [0.24000] | Pred: [0.24764]
# True: [0.16800] | Pred: [0.16698]
# True: [0.28200] | Pred: [0.27589]

# %%
scatter_accuracy(ys, preds)

# %%
GAMMA_R.save(gm4_best_save)
GAMMA_R.save_weights(gm4_best_save_weights)
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <__main__.ResnetBlock object at 0x7f45602adca0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <__main__.ResnetBlock object at 0x7f45602b6d90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f45601ea640>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f45601ea550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f4560174040>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.regularization.dropout.Dropout object at 0x7f4560174490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f4560174d90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f45601784c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.dense.Dense object at 0x7f45601789d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.regularization.dropout.Dropout object at 0x7f4560178e20>, because it is not built.
# WARNING:absl:Found untraced functions such as call, call while saving (showing 2 of 2). These functions will not be directly callable after loading.

# %%
GAMMA_RTrainHistDf.to_csv(gm4_save_root/"train_hist.csv")
